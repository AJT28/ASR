# %%
# !pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\acer\appdata\roaming\python\python312\site-packages (3.14.1)
# Requirement already satisfied: typing-extensions in c:\users\acer\anaconda3\lib\site-packages (from SpeechRecognition) (4.11.0)

# %%
import nltk
nltk.download('cmudict')
# Out:
# [nltk_data] Downloading package cmudict to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!
# True

# %%
import ffmpeg
import os
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor

# Supported input file formats
SUPPORTED_FORMATS = (".mp3", ".aac", ".flac", ".ogg", ".opus", ".m4a", ".wav")

def convert_audio_to_wav(input_path, output_path, sample_rate=16000):
    """Converts any audio file to WAV format."""
    if os.path.exists(output_path):  
        return f"Skipping {os.path.basename(input_path)} (Already converted)"

    try:
        ffmpeg.input(input_path).output(output_path, ar=sample_rate, ac=1).run(overwrite_output=True, quiet=True)
        return f"✅ Converted {os.path.basename(input_path)}"
    except ffmpeg.Error as e:
        return f"❌ Error converting {os.path.basename(input_path)}: {e}"

def convert_dataset_to_wav(input_folder, output_folder, sample_rate=16000, max_workers=4):
    """Convert all supported audio files to WAV format using multi-threading."""
    
    os.makedirs(output_folder, exist_ok=True)  # Ensure output directory exists

    # Get all supported audio files
    audio_files = [f for f in os.listdir(input_folder) if f.endswith(SUPPORTED_FORMATS)]
    new_files = [f for f in audio_files if not os.path.exists(os.path.join(output_folder, os.path.splitext(f)[0] + ".wav"))]

    if not new_files:
        print(f"✅ No new files to convert in {input_folder}. Skipping conversion.")
        return

    print(f"🔄 Converting {len(new_files)} new files in {input_folder}...")

    # Use ThreadPoolExecutor to process multiple files in parallel
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        tasks = [
            executor.submit(
                convert_audio_to_wav, 
                os.path.join(input_folder, file), 
                os.path.join(output_folder, os.path.splitext(file)[0] + ".wav"),  
                sample_rate
            )
            for file in new_files
        ]

        for future in tqdm(tasks, desc=f"Processing {input_folder}"):
            print(future.result())  # Print conversion status

# Example usage
dataset_folders = [
    r"C:\ASR\raw_audio",  # Change this to your input folder
]

output_folders = [
    r"C:\ASR\converted_audio",  # Change this to your output folder
]
    
# Convert all audio files in dataset folders
for in_folder, out_folder in zip(dataset_folders, output_folders):
    convert_dataset_to_wav(in_folder, out_folder, max_workers=6)
# Out:
# ✅ No new files to convert in C:\ASR\raw_audio. Skipping conversion.

# %%
import os
import shutil
import numpy as np
import soundfile as sf
import noisereduce as nr
import librosa
import librosa.effects
import logging
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor
from sklearn.model_selection import train_test_split
from phonemizer import phonemize
import fasttext
import subprocess

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# Paths
input_folder = r"C:\ASR\converted_audio"
denoised_folder = r"C:\ASR\denoised_audio"
FEATURES_OUTPUT_FOLDER = r"C:\ASR\features"
transcript_file = r"C:\ASR\transcripts.txt"
fasttext_model_path = r"C:\ASR\models\lid.176.ftz"

# Ensure base directories exist
os.makedirs(denoised_folder, exist_ok=True)
os.makedirs(FEATURES_OUTPUT_FOLDER, exist_ok=True)
for subfolder in ["mel", "mfcc", "chroma", "phonemes", "transcript", "train", "test"]:
    os.makedirs(os.path.join(FEATURES_OUTPUT_FOLDER, subfolder), exist_ok=True)

# Load FastText model
lang_model = fasttext.load_model(fasttext_model_path)

def load_transcripts_from_file(file_path):
    transcript_dict = {}
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            parts = line.strip().split("\t")
            if len(parts) == 2:
                file_id, transcript = parts
                transcript_dict[file_id.strip()] = transcript.strip()
    return transcript_dict

transcript_dict = load_transcripts_from_file(transcript_file)

# Phonemization with espeak-ng
def phoneme_conversion_espeak(text):
    words = text.split()
    phonemes = []
    espeak_path = r"C:\Program Files\eSpeak NG\espeak-ng.exe"  # Replace with the actual path

    for word in words:
        try:
            process = subprocess.Popen(
                [espeak_path, "-q", "-v", "es", "--ipa", word],  # Added -q option
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=True,
                encoding="utf-8",
                errors="replace",
            )
            stdout, stderr = process.communicate()
            if stdout:
                phoneme_seq = stdout.strip().split()
                phonemes.append(" ".join(phoneme_seq))
            else:
                phonemes.append("[UNK]")
                logging.warning(f"espeak-ng failed for '{word}': {stderr.strip()}")
        except FileNotFoundError:
            logging.error(f"espeak-ng not found at '{espeak_path}'.")
            return "[ERROR: espeak-ng not found]"
        except Exception as e:
            logging.error(f"espeak-ng error for '{word}': {e}")
            phonemes.append("[UNK]")
    return " | ".join(phonemes)

# Audio processing
def process_audio(input_path, features_folder, sample_rate=16000):
    try:
        base_name = os.path.basename(input_path).replace(".wav", "")
        denoised_path = os.path.join(denoised_folder, base_name + "_denoised.wav")

        # Denoise if needed
        if os.path.exists(denoised_path):
            audio, sr = librosa.load(denoised_path, sr=sample_rate)
            audio, _ = librosa.effects.trim(audio, top_db=20)
        else:
            raw_audio, sr = librosa.load(input_path, sr=sample_rate)
            audio = nr.reduce_noise(y=raw_audio, sr=sr)
            audio, _ = librosa.effects.trim(audio, top_db=20)
            sf.write(denoised_path, audio, sr)

        extracted = []
        transcript_words = None

        # Get transcript (try from file)
        transcript_from_file = transcript_dict.get(base_name, "")
        if transcript_from_file:
            logging.info(f"📜 Using existing transcript for {base_name}: {transcript_from_file}")
            print(f"📜 Transcript used [file - {base_name}]: {transcript_from_file}")
            transcript_words = transcript_from_file.split()
        else:
            logging.warning(f"⚠ No transcript found for {base_name}.")

        # Extract Phonemes if transcript is available
        phoneme_path = os.path.join(features_folder, "phonemes", base_name + ".npy")
        if not os.path.exists(phoneme_path) and transcript_words:
            transcript_text = " ".join(transcript_words)
            phonemes = phoneme_conversion_espeak(transcript_text).split(" | ")
            np.save(phoneme_path, np.array(phonemes, dtype=object))
            extracted.append("Phonemes")

        # Save Transcript if found
        transcript_path = os.path.join(features_folder, "transcript", base_name + ".npy")
        if not os.path.exists(transcript_path) and transcript_words:
            np.save(transcript_path, np.array(transcript_words, dtype=object))
            extracted.append("Transcript")

        # Extract other features (independent of transcript)
        mfccs_path = os.path.join(features_folder, "mfcc", base_name + ".npy")
        if not os.path.exists(mfccs_path):
            mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13)
            np.save(mfccs_path, mfccs.T)
            extracted.append("MFCC")

        mel_path = os.path.join(features_folder, "mel", base_name + ".npy")
        if not os.path.exists(mel_path):
            mel = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=128)
            mel_db = librosa.power_to_db(mel, ref=np.max)
            np.save(mel_path, mel_db.T)
            extracted.append("Mel")

        chroma_path = os.path.join(features_folder, "chroma", base_name + ".npy")
        if not os.path.exists(chroma_path):
            chroma = librosa.feature.chroma_stft(y=audio, sr=sr)
            np.save(chroma_path, chroma.T)
            extracted.append("Chroma")

        if not extracted and os.path.exists(os.path.join(features_folder, "mfcc", base_name + ".npy")):
            return f"✅ Skipping {base_name}, features already extracted."
        elif not extracted:
            return f"⚠ Skipping {base_name}, no new features extracted."
        else:
            return f"✅ Processed {base_name}: {', '.join(extracted)}"

    except Exception as e:
        logging.error(f"❌ Error processing {input_path}: {e}")
        return f"❌ Failed {os.path.basename(input_path)}"

# Batch processing with check for existing features in train/test
def process_new_audio(input_folder, features_folder, max_workers=6):
    audio_files = [f for f in os.listdir(input_folder) if f.endswith(".wav")]
    files_to_process = []

    for audio_file in audio_files:
        base_name = audio_file.replace(".wav", "")
        train_dir = os.path.join(features_folder, "train", base_name)
        test_dir = os.path.join(features_folder, "test", base_name)
        feature_files_exist_in_train = os.path.exists(os.path.join(train_dir, "mfcc.npy"))
        feature_files_exist_in_test = os.path.exists(os.path.join(test_dir, "mfcc.npy"))

        if not feature_files_exist_in_train and not feature_files_exist_in_test:
            files_to_process.append(audio_file)
        else:
            logging.info(f"⏭️ Skipping {base_name}, features found in train or test.")

    if not files_to_process:
        logging.info("✅ No new audio files to process.")
        return

    logging.info(f"📢 Processing {len(files_to_process)} new audio files...")
    tasks = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        for file in files_to_process:
            tasks.append(executor.submit(process_audio, os.path.join(input_folder, file), features_folder))
        for future in tqdm(tasks, desc="🔄 Processing new audio"):
            logging.info(future.result())

# Dataset splitter (modified to only consider unprocessed files)
def split_new_dataset(features_folder, test_size=0.2):
    all_base_names = set()
    audio_files = [f for f in os.listdir(input_folder) if f.endswith(".wav")]

    for audio_file in audio_files:
        base_name = audio_file.replace(".wav", "")
        train_dir = os.path.join(features_folder, "train", base_name)
        test_dir = os.path.join(features_folder, "test", base_name)
        feature_files_exist_in_train = os.path.exists(os.path.join(train_dir, "mfcc.npy"))
        feature_files_exist_in_test = os.path.exists(os.path.join(test_dir, "mfcc.npy"))

        if not feature_files_exist_in_train and not feature_files_exist_in_test:
            # Only consider files that haven't been split yet
            phoneme_path = os.path.join(features_folder, "phonemes", base_name + ".npy")
            if os.path.exists(phoneme_path):
                all_base_names.add(base_name)

    complete_sets = []
    for base in all_base_names:
        files = [
            os.path.join("mfcc", base + ".npy"),
            os.path.join("mel", base + ".npy"),
            os.path.join("chroma", base + ".npy"),
            os.path.join("phonemes", base + ".npy"),
            os.path.join("transcript", base + ".npy")
        ]
        if all(os.path.exists(os.path.join(features_folder, feature_type, base + ".npy")) for feature_type in ["mfcc", "mel", "chroma", "phonemes", "transcript"]):
            complete_sets.append(base)

    if len(complete_sets) < 2:
        logging.warning(f"⚠ Not enough new complete feature sets to split (found {len(complete_sets)}).")
        return

    train_files, test_files = train_test_split(complete_sets, test_size=test_size, random_state=42)

    os.makedirs(os.path.join(features_folder, "train"), exist_ok=True)
    os.makedirs(os.path.join(features_folder, "test"), exist_ok=True)

    for base in train_files:
        output_dir = os.path.join(features_folder, "train", base)
        os.makedirs(output_dir, exist_ok=True)
        for feature_type in ["mfcc", "mel", "chroma", "phonemes", "transcript"]:
            src_path = os.path.join(features_folder, feature_type, base + ".npy")
            dst_path = os.path.join(output_dir, feature_type + ".npy")
            if os.path.exists(src_path):
                shutil.move(src_path, dst_path)

    for base in test_files:
        output_dir = os.path.join(features_folder, "test", base)
        os.makedirs(output_dir, exist_ok=True)
        for feature_type in ["mfcc", "mel", "chroma", "phonemes", "transcript"]:
            src_path = os.path.join(features_folder, feature_type, base + ".npy")
            dst_path = os.path.join(output_dir, feature_type + ".npy")
            if os.path.exists(src_path):
                shutil.move(src_path, dst_path)

    logging.info(f"📂 Split new data: {len(train_files)} train, {len(test_files)} test.")

# Execute
if __name__ == "__main__":
    # Paths (already defined at the beginning)

    # Ensure directories exist (already handled)

    # Load transcripts (already handled)
    transcript_dict = load_transcripts_from_file(transcript_file)

    # Load FastText model (already handled)
    lang_model = fasttext.load_model(fasttext_model_path)

    # Execute processing for new audio only
    process_new_audio(input_folder, FEATURES_OUTPUT_FOLDER)

    # Execute data splitting for newly processed data
    split_new_dataset(FEATURES_OUTPUT_FOLDER)

    logging.info("✅ Feature extraction and data splitting for new files complete.")
# Out:
# 2025-04-11 13:12:42,118 - INFO - ⏭️ Skipping 10367_10282_000000, features found in train or test.
# 2025-04-11 13:12:42,118 - INFO - ⏭️ Skipping 10367_10282_000001, features found in train or test.
# 2025-04-11 13:12:42,119 - INFO - ⏭️ Skipping 10367_10282_000002, features found in train or test.
# 2025-04-11 13:12:42,121 - INFO - ⏭️ Skipping 10367_10282_000003, features found in train or test.
# 2025-04-11 13:12:42,122 - INFO - ⏭️ Skipping 10367_10282_000004, features found in train or test.
# 2025-04-11 13:12:42,123 - INFO - ⏭️ Skipping 10367_10282_000005, features found in train or test.
# 2025-04-11 13:12:42,124 - INFO - ⏭️ Skipping 10367_10282_000006, features found in train or test.
# 2025-04-11 13:12:42,124 - INFO - ⏭️ Skipping 10367_10282_000007, features found in train or test.
# 2025-04-11 13:12:42,126 - INFO - ⏭️ Skipping 10367_10282_000008, features found in train or test.
# 2025-04-11 13:12:42,126 - INFO - ⏭️ Skipping 10367_10282_000009, features found in train or test.
# 2025-04-11 13:12:42,128 - INFO - ⏭️ Skipping 10367_10282_000010, features found in train or test.
# 2025-04-11 13:12:42,129 - INFO - ⏭️ Skipping 10367_10282_000011, features found in train or test.
# 2025-04-11 13:12:42,130 - INFO - ⏭️ Skipping 10367_10282_000012, features found in train or test.
# 2025-04-11 13:12:42,131 - INFO - ⏭️ Skipping 10367_10282_000013, features found in train or test.
# 2025-04-11 13:12:42,133 - INFO - ⏭️ Skipping 10367_10282_000014, features found in train or test.
# 2025-04-11 13:12:42,135 - INFO - ⏭️ Skipping 10367_10282_000015, features found in train or test.
# 2025-04-11 13:12:42,135 - INFO - ⏭️ Skipping 10367_10282_000016, features found in train or test.
# 2025-04-11 13:12:42,137 - INFO - ⏭️ Skipping 10367_10282_000017, features found in train or test.
# 2025-04-11 13:12:42,137 - INFO - ⏭️ Skipping 10367_10282_000018, features found in train or test.
# 2025-04-11 13:12:42,139 - INFO - ⏭️ Skipping 10367_10282_000019, features found in train or test.
# 2025-04-11 13:12:42,139 - INFO - ⏭️ Skipping 10367_10282_000020, features found in train or test.
# 2025-04-11 13:12:42,140 - INFO - ⏭️ Skipping 10367_10282_000021, features found in train or test.
# 2025-04-11 13:12:42,141 - INFO - ⏭️ Skipping 10367_10282_000022, features found in train or test.
# 2025-04-11 13:12:42,143 - INFO - ⏭️ Skipping 10367_10282_000023, features found in train or test.
# 2025-04-11 13:12:42,143 - INFO - ⏭️ Skipping 10367_10282_000024, features found in train or test.
# 2025-04-11 13:12:42,145 - INFO - ⏭️ Skipping 10367_10282_000025, features found in train or test.
# 2025-04-11 13:12:42,147 - INFO - ⏭️ Skipping 10367_10282_000026, features found in train or test.
# 2025-04-11 13:12:42,152 - INFO - ⏭️ Skipping 10367_10282_000027, features found in train or test.
# 2025-04-11 13:12:42,156 - INFO - ⏭️ Skipping 10367_10282_000028, features found in train or test.
# 2025-04-11 13:12:42,158 - INFO - ⏭️ Skipping 10367_10282_000029, features found in train or test.
# 2025-04-11 13:12:42,161 - INFO - ⏭️ Skipping 10367_10282_000030, features found in train or test.
# 2025-04-11 13:12:42,162 - INFO - ⏭️ Skipping 10367_10282_000031, features found in train or test.
# 2025-04-11 13:12:42,163 - INFO - ⏭️ Skipping 10367_10282_000032, features found in train or test.
# 2025-04-11 13:12:42,163 - INFO - ⏭️ Skipping 10367_10282_000033, features found in train or test.
# 2025-04-11 13:12:42,164 - INFO - ⏭️ Skipping 10367_10282_000034, features found in train or test.
# 2025-04-11 13:12:42,166 - INFO - ⏭️ Skipping 10367_10282_000035, features found in train or test.
# 2025-04-11 13:12:42,168 - INFO - ⏭️ Skipping 10367_10282_000036, features found in train or test.
# 2025-04-11 13:12:42,170 - INFO - ⏭️ Skipping 10367_10282_000037, features found in train or test.
# 2025-04-11 13:12:42,171 - INFO - ⏭️ Skipping 10367_10282_000038, features found in train or test.
# 2025-04-11 13:12:42,174 - INFO - ⏭️ Skipping 10367_10282_000039, features found in train or test.
# 2025-04-11 13:12:42,176 - INFO - ⏭️ Skipping 10367_10282_000040, features found in train or test.
# 2025-04-11 13:12:42,177 - INFO - ⏭️ Skipping 10367_10282_000041, features found in train or test.
# 2025-04-11 13:12:42,179 - INFO - ⏭️ Skipping 10367_10282_000042, features found in train or test.
# 2025-04-11 13:12:42,180 - INFO - ⏭️ Skipping 10367_10282_000043, features found in train or test.
# 2025-04-11 13:12:42,182 - INFO - ⏭️ Skipping 10367_10282_000044, features found in train or test.
# 2025-04-11 13:12:42,182 - INFO - ⏭️ Skipping 10367_10282_000045, features found in train or test.
# 2025-04-11 13:12:42,184 - INFO - ⏭️ Skipping 10367_10282_000046, features found in train or test.
# 2025-04-11 13:12:42,186 - INFO - ⏭️ Skipping 10367_10282_000047, features found in train or test.
# 2025-04-11 13:12:42,188 - INFO - ⏭️ Skipping 10367_10282_000048, features found in train or test.
# 2025-04-11 13:12:42,191 - INFO - ⏭️ Skipping 10367_10282_000049, features found in train or test.
# 2025-04-11 13:12:42,193 - INFO - ⏭️ Skipping 10367_10282_000050, features found in train or test.
# 2025-04-11 13:12:42,195 - INFO - ⏭️ Skipping 10367_10282_000051, features found in train or test.
# 2025-04-11 13:12:42,196 - INFO - ⏭️ Skipping 10367_10282_000052, features found in train or test.
# 2025-04-11 13:12:42,197 - INFO - ⏭️ Skipping 10367_10282_000053, features found in train or test.
# 2025-04-11 13:12:42,199 - INFO - ⏭️ Skipping 10367_10282_000054, features found in train or test.
# 2025-04-11 13:12:42,201 - INFO - ⏭️ Skipping 10367_10282_000055, features found in train or test.
# 2025-04-11 13:12:42,203 - INFO - ⏭️ Skipping 10367_10282_000056, features found in train or test.
# 2025-04-11 13:12:42,207 - INFO - ⏭️ Skipping 10367_10282_000057, features found in train or test.
# 2025-04-11 13:12:42,208 - INFO - ⏭️ Skipping 10367_10282_000058, features found in train or test.
# 2025-04-11 13:12:42,210 - INFO - ⏭️ Skipping 10367_10282_000059, features found in train or test.
# 2025-04-11 13:12:42,211 - INFO - ⏭️ Skipping 10367_10282_000060, features found in train or test.
# 2025-04-11 13:12:42,212 - INFO - ⏭️ Skipping 10367_10282_000061, features found in train or test.
# 2025-04-11 13:12:42,212 - INFO - ⏭️ Skipping 10367_10282_000062, features found in train or test.
# 2025-04-11 13:12:42,214 - INFO - ⏭️ Skipping 10367_10282_000063, features found in train or test.
# 2025-04-11 13:12:42,215 - INFO - ⏭️ Skipping 10367_10282_000064, features found in train or test.
# 2025-04-11 13:12:42,215 - INFO - ⏭️ Skipping 10367_10282_000065, features found in train or test.
# 2025-04-11 13:12:42,220 - INFO - ⏭️ Skipping 10367_10282_000066, features found in train or test.
# 2025-04-11 13:12:42,223 - INFO - ⏭️ Skipping 10367_10282_000067, features found in train or test.
# 2025-04-11 13:12:42,224 - INFO - ⏭️ Skipping 10367_10282_000068, features found in train or test.
# 2025-04-11 13:12:42,225 - INFO - ⏭️ Skipping 10367_10282_000069, features found in train or test.
# 2025-04-11 13:12:42,225 - INFO - ⏭️ Skipping 10367_10282_000070, features found in train or test.
# 2025-04-11 13:12:42,226 - INFO - ⏭️ Skipping 10367_10282_000071, features found in train or test.
# 2025-04-11 13:12:42,227 - INFO - ⏭️ Skipping 10367_10282_000072, features found in train or test.
# 2025-04-11 13:12:42,228 - INFO - ⏭️ Skipping 10367_10282_000073, features found in train or test.
# 2025-04-11 13:12:42,229 - INFO - ⏭️ Skipping 10367_10282_000074, features found in train or test.
# 2025-04-11 13:12:42,230 - INFO - ⏭️ Skipping 10367_10282_000075, features found in train or test.
# 2025-04-11 13:12:42,231 - INFO - ⏭️ Skipping 10367_10282_000076, features found in train or test.
# 2025-04-11 13:12:42,233 - INFO - ⏭️ Skipping 10367_10282_000077, features found in train or test.
# 2025-04-11 13:12:42,234 - INFO - ⏭️ Skipping 10367_10282_000078, features found in train or test.
# 2025-04-11 13:12:42,235 - INFO - ⏭️ Skipping 10367_10282_000079, features found in train or test.
# 2025-04-11 13:12:42,236 - INFO - ⏭️ Skipping 10367_10282_000080, features found in train or test.
# 2025-04-11 13:12:42,238 - INFO - ⏭️ Skipping 10367_10282_000081, features found in train or test.
# 2025-04-11 13:12:42,241 - INFO - ⏭️ Skipping 10367_10282_000082, features found in train or test.
# 2025-04-11 13:12:42,243 - INFO - ⏭️ Skipping 10367_10282_000083, features found in train or test.
# 2025-04-11 13:12:42,244 - INFO - ⏭️ Skipping 10367_10282_000084, features found in train or test.
# 2025-04-11 13:12:42,246 - INFO - ⏭️ Skipping 1075_567_000000, features found in train or test.
# 2025-04-11 13:12:42,247 - INFO - ⏭️ Skipping 1075_567_000001, features found in train or test.
# 2025-04-11 13:12:42,247 - INFO - ⏭️ Skipping 1075_567_000002, features found in train or test.
# 2025-04-11 13:12:42,248 - INFO - ⏭️ Skipping 1075_567_000003, features found in train or test.
# 2025-04-11 13:12:42,250 - INFO - ⏭️ Skipping 1075_567_000004, features found in train or test.
# 2025-04-11 13:12:42,251 - INFO - ⏭️ Skipping 1075_567_000005, features found in train or test.
# 2025-04-11 13:12:42,252 - INFO - ⏭️ Skipping 1075_567_000006, features found in train or test.
# 2025-04-11 13:12:42,253 - INFO - ⏭️ Skipping 1075_567_000007, features found in train or test.
# 2025-04-11 13:12:42,254 - INFO - ⏭️ Skipping 1075_567_000008, features found in train or test.
# 2025-04-11 13:12:42,254 - INFO - ⏭️ Skipping 1075_567_000009, features found in train or test.
# 2025-04-11 13:12:42,254 - INFO - ⏭️ Skipping 1075_567_000010, features found in train or test.
# 2025-04-11 13:12:42,254 - INFO - ⏭️ Skipping 1075_567_000011, features found in train or test.
# 2025-04-11 13:12:42,262 - INFO - ⏭️ Skipping 1075_567_000012, features found in train or test.
# 2025-04-11 13:12:42,264 - INFO - ⏭️ Skipping 1075_567_000013, features found in train or test.
# 2025-04-11 13:12:42,264 - INFO - ⏭️ Skipping 1075_567_000014, features found in train or test.
# 2025-04-11 13:12:42,264 - INFO - ⏭️ Skipping 1075_567_000015, features found in train or test.
# 2025-04-11 13:12:42,264 - INFO - ⏭️ Skipping 1075_567_000016, features found in train or test.
# 2025-04-11 13:12:42,268 - INFO - ⏭️ Skipping 1075_567_000017, features found in train or test.
# 2025-04-11 13:12:42,269 - INFO - ⏭️ Skipping 1075_567_000018, features found in train or test.
# 2025-04-11 13:12:42,270 - INFO - ⏭️ Skipping 1075_567_000019, features found in train or test.
# 2025-04-11 13:12:42,270 - INFO - ⏭️ Skipping 1075_567_000020, features found in train or test.
# 2025-04-11 13:12:42,270 - INFO - ⏭️ Skipping 1075_567_000021, features found in train or test.
# 2025-04-11 13:12:42,274 - INFO - ⏭️ Skipping 1075_567_000022, features found in train or test.
# 2025-04-11 13:12:42,274 - INFO - ⏭️ Skipping 1075_567_000023, features found in train or test.
# 2025-04-11 13:12:42,274 - INFO - ⏭️ Skipping 1075_567_000024, features found in train or test.
# 2025-04-11 13:12:42,274 - INFO - ⏭️ Skipping 1075_567_000025, features found in train or test.
# 2025-04-11 13:12:42,274 - INFO - ⏭️ Skipping 1075_567_000026, features found in train or test.
# 2025-04-11 13:12:42,274 - INFO - ⏭️ Skipping 1075_567_000027, features found in train or test.
# 2025-04-11 13:12:42,284 - INFO - ⏭️ Skipping 1075_567_000028, features found in train or test.
# 2025-04-11 13:12:42,285 - INFO - ⏭️ Skipping 1075_567_000029, features found in train or test.
# 2025-04-11 13:12:42,286 - INFO - ⏭️ Skipping 1075_567_000030, features found in train or test.
# 2025-04-11 13:12:42,288 - INFO - ⏭️ Skipping 1075_567_000031, features found in train or test.
# 2025-04-11 13:12:42,288 - INFO - ⏭️ Skipping 1075_567_000032, features found in train or test.
# 2025-04-11 13:12:42,291 - INFO - ⏭️ Skipping 1075_567_000033, features found in train or test.
# 2025-04-11 13:12:42,293 - INFO - ⏭️ Skipping 1075_567_000034, features found in train or test.
# 2025-04-11 13:12:42,297 - INFO - ⏭️ Skipping 1075_567_000035, features found in train or test.
# 2025-04-11 13:12:42,297 - INFO - ⏭️ Skipping 1075_567_000036, features found in train or test.
# 2025-04-11 13:12:42,299 - INFO - ⏭️ Skipping 1075_567_000037, features found in train or test.
# 2025-04-11 13:12:42,299 - INFO - ⏭️ Skipping 1075_567_000038, features found in train or test.
# 2025-04-11 13:12:42,301 - INFO - ⏭️ Skipping 1075_567_000039, features found in train or test.
# 2025-04-11 13:12:42,302 - INFO - ⏭️ Skipping 1075_567_000040, features found in train or test.
# 2025-04-11 13:12:42,303 - INFO - ⏭️ Skipping 1075_567_000041, features found in train or test.
# 2025-04-11 13:12:42,304 - INFO - ⏭️ Skipping 1075_567_000042, features found in train or test.
# 2025-04-11 13:12:42,305 - INFO - ⏭️ Skipping 1075_567_000043, features found in train or test.
# 2025-04-11 13:12:42,305 - INFO - ⏭️ Skipping 1075_567_000044, features found in train or test.
# 2025-04-11 13:12:42,306 - INFO - ⏭️ Skipping 1075_567_000045, features found in train or test.
# 2025-04-11 13:12:42,307 - INFO - ⏭️ Skipping 1075_567_000046, features found in train or test.
# 2025-04-11 13:12:42,308 - INFO - ⏭️ Skipping 1075_567_000047, features found in train or test.
# 2025-04-11 13:12:42,308 - INFO - ⏭️ Skipping 1075_567_000048, features found in train or test.
# 2025-04-11 13:12:42,311 - INFO - ⏭️ Skipping 1075_567_000049, features found in train or test.
# 2025-04-11 13:12:42,316 - INFO - ⏭️ Skipping 1075_567_000050, features found in train or test.
# 2025-04-11 13:12:42,316 - INFO - ⏭️ Skipping 1075_567_000051, features found in train or test.
# 2025-04-11 13:12:42,318 - INFO - ⏭️ Skipping 1075_567_000052, features found in train or test.
# 2025-04-11 13:12:42,319 - INFO - ⏭️ Skipping 1075_567_000053, features found in train or test.
# 2025-04-11 13:12:42,320 - INFO - ⏭️ Skipping 1075_567_000054, features found in train or test.
# 2025-04-11 13:12:42,321 - INFO - ⏭️ Skipping 1075_567_000055, features found in train or test.
# 2025-04-11 13:12:42,322 - INFO - ⏭️ Skipping 1075_567_000056, features found in train or test.
# 2025-04-11 13:12:42,323 - INFO - ⏭️ Skipping 1075_567_000057, features found in train or test.
# 2025-04-11 13:12:42,324 - INFO - ⏭️ Skipping 1075_567_000058, features found in train or test.
# 2025-04-11 13:12:42,325 - INFO - ⏭️ Skipping 1075_567_000059, features found in train or test.
# 2025-04-11 13:12:42,326 - INFO - ⏭️ Skipping 1075_567_000060, features found in train or test.
# 2025-04-11 13:12:42,326 - INFO - ⏭️ Skipping 1075_567_000061, features found in train or test.
# 2025-04-11 13:12:42,327 - INFO - ⏭️ Skipping 1075_567_000062, features found in train or test.
# 2025-04-11 13:12:42,328 - INFO - ⏭️ Skipping 1075_567_000063, features found in train or test.
# 2025-04-11 13:12:42,330 - INFO - ⏭️ Skipping 1075_567_000064, features found in train or test.
# 2025-04-11 13:12:42,331 - INFO - ⏭️ Skipping 1075_567_000065, features found in train or test.
# 2025-04-11 13:12:42,332 - INFO - ⏭️ Skipping 1075_567_000066, features found in train or test.
# 2025-04-11 13:12:42,332 - INFO - ⏭️ Skipping 1075_567_000067, features found in train or test.
# 2025-04-11 13:12:42,334 - INFO - ⏭️ Skipping 1075_567_000068, features found in train or test.
# 2025-04-11 13:12:42,337 - INFO - ⏭️ Skipping 1075_567_000069, features found in train or test.
# 2025-04-11 13:12:42,340 - INFO - ⏭️ Skipping 1075_567_000070, features found in train or test.
# 2025-04-11 13:12:42,342 - INFO - ⏭️ Skipping 1075_567_000071, features found in train or test.
# 2025-04-11 13:12:42,343 - INFO - ⏭️ Skipping 1075_567_000072, features found in train or test.
# 2025-04-11 13:12:42,344 - INFO - ⏭️ Skipping 1075_567_000073, features found in train or test.
# 2025-04-11 13:12:42,345 - INFO - ⏭️ Skipping 1075_567_000074, features found in train or test.
# 2025-04-11 13:12:42,345 - INFO - ⏭️ Skipping 1075_567_000075, features found in train or test.
# 2025-04-11 13:12:42,346 - INFO - ⏭️ Skipping 1075_567_000076, features found in train or test.
# 2025-04-11 13:12:42,347 - INFO - ⏭️ Skipping 1075_567_000077, features found in train or test.
# 2025-04-11 13:12:42,348 - INFO - ⏭️ Skipping 1075_567_000078, features found in train or test.
# 2025-04-11 13:12:42,350 - INFO - ⏭️ Skipping 1075_567_000079, features found in train or test.
# 2025-04-11 13:12:42,351 - INFO - ⏭️ Skipping 1075_567_000080, features found in train or test.
# 2025-04-11 13:12:42,352 - INFO - ⏭️ Skipping 1075_567_000081, features found in train or test.
# 2025-04-11 13:12:42,353 - INFO - ⏭️ Skipping 1075_567_000082, features found in train or test.
# 2025-04-11 13:12:42,354 - INFO - ⏭️ Skipping 1075_567_000083, features found in train or test.
# 2025-04-11 13:12:42,355 - INFO - ⏭️ Skipping 1075_567_000084, features found in train or test.
# 2025-04-11 13:12:42,357 - INFO - ⏭️ Skipping 1075_567_000085, features found in train or test.
# 2025-04-11 13:12:42,359 - INFO - ⏭️ Skipping 1075_567_000086, features found in train or test.
# 2025-04-11 13:12:42,359 - INFO - ⏭️ Skipping 1075_567_000087, features found in train or test.
# 2025-04-11 13:12:42,359 - INFO - ⏭️ Skipping 1075_567_000088, features found in train or test.
# 2025-04-11 13:12:42,359 - INFO - ⏭️ Skipping 1075_567_000089, features found in train or test.
# 2025-04-11 13:12:42,368 - INFO - ⏭️ Skipping 1075_567_000090, features found in train or test.
# 2025-04-11 13:12:42,368 - INFO - ⏭️ Skipping 1075_567_000091, features found in train or test.
# 2025-04-11 13:12:42,369 - INFO - ⏭️ Skipping 1075_567_000092, features found in train or test.
# 2025-04-11 13:12:42,370 - INFO - ⏭️ Skipping 1075_567_000093, features found in train or test.
# 2025-04-11 13:12:42,371 - INFO - ⏭️ Skipping 1075_567_000094, features found in train or test.
# 2025-04-11 13:12:42,372 - INFO - ⏭️ Skipping 1075_567_000095, features found in train or test.
# 2025-04-11 13:12:42,373 - INFO - ⏭️ Skipping 1075_567_000096, features found in train or test.
# 2025-04-11 13:12:42,374 - INFO - ⏭️ Skipping 1075_567_000097, features found in train or test.
# 2025-04-11 13:12:42,374 - INFO - ⏭️ Skipping 1075_567_000098, features found in train or test.
# 2025-04-11 13:12:42,376 - INFO - ⏭️ Skipping 1075_567_000099, features found in train or test.
# 2025-04-11 13:12:42,377 - INFO - ⏭️ Skipping 1075_567_000100, features found in train or test.
# 2025-04-11 13:12:42,378 - INFO - ⏭️ Skipping 1075_567_000101, features found in train or test.
# 2025-04-11 13:12:42,378 - INFO - ⏭️ Skipping 1075_567_000102, features found in train or test.
# 2025-04-11 13:12:42,379 - INFO - ⏭️ Skipping 1075_567_000103, features found in train or test.
# 2025-04-11 13:12:42,380 - INFO - ⏭️ Skipping 1075_567_000104, features found in train or test.
# 2025-04-11 13:12:42,381 - INFO - ⏭️ Skipping 1075_567_000105, features found in train or test.
# 2025-04-11 13:12:42,382 - INFO - ⏭️ Skipping 1075_567_000106, features found in train or test.
# 2025-04-11 13:12:42,382 - INFO - ⏭️ Skipping 1075_567_000107, features found in train or test.
# 2025-04-11 13:12:42,384 - INFO - ⏭️ Skipping 1075_567_000108, features found in train or test.
# 2025-04-11 13:12:42,384 - INFO - ⏭️ Skipping 1075_567_000109, features found in train or test.
# 2025-04-11 13:12:42,385 - INFO - ⏭️ Skipping 1075_567_000110, features found in train or test.
# 2025-04-11 13:12:42,385 - INFO - ⏭️ Skipping 1075_567_000111, features found in train or test.
# 2025-04-11 13:12:42,388 - INFO - ⏭️ Skipping 1075_567_000112, features found in train or test.
# 2025-04-11 13:12:42,390 - INFO - ⏭️ Skipping 1075_567_000113, features found in train or test.
# 2025-04-11 13:12:42,390 - INFO - ⏭️ Skipping 1075_567_000114, features found in train or test.
# 2025-04-11 13:12:42,392 - INFO - ⏭️ Skipping 1075_567_000115, features found in train or test.
# 2025-04-11 13:12:42,394 - INFO - ⏭️ Skipping 1075_567_000116, features found in train or test.
# 2025-04-11 13:12:42,394 - INFO - ⏭️ Skipping 1075_567_000117, features found in train or test.
# 2025-04-11 13:12:42,394 - INFO - ⏭️ Skipping 1075_567_000118, features found in train or test.
# 2025-04-11 13:12:42,394 - INFO - ⏭️ Skipping 1075_567_000119, features found in train or test.
# 2025-04-11 13:12:42,394 - INFO - ⏭️ Skipping 1075_567_000120, features found in train or test.
# 2025-04-11 13:12:42,394 - INFO - ⏭️ Skipping 1075_567_000121, features found in train or test.
# 2025-04-11 13:12:42,398 - INFO - ⏭️ Skipping 1075_567_000122, features found in train or test.
# 2025-04-11 13:12:42,398 - INFO - ⏭️ Skipping 11670_10604_000000, features found in train or test.
# 2025-04-11 13:12:42,398 - INFO - ⏭️ Skipping 11670_10604_000001, features found in train or test.
# 2025-04-11 13:12:42,401 - INFO - ⏭️ Skipping 11670_10604_000002, features found in train or test.
# 2025-04-11 13:12:42,402 - INFO - ⏭️ Skipping 11670_10604_000003, features found in train or test.
# 2025-04-11 13:12:42,402 - INFO - ⏭️ Skipping 11670_10604_000004, features found in train or test.
# 2025-04-11 13:12:42,403 - INFO - ⏭️ Skipping 11670_10604_000005, features found in train or test.
# 2025-04-11 13:12:42,403 - INFO - ⏭️ Skipping 11670_10604_000006, features found in train or test.
# 2025-04-11 13:12:42,404 - INFO - ⏭️ Skipping 11670_10604_000007, features found in train or test.
# 2025-04-11 13:12:42,405 - INFO - ⏭️ Skipping 11670_10604_000008, features found in train or test.
# 2025-04-11 13:12:42,406 - INFO - ⏭️ Skipping 11670_10604_000009, features found in train or test.
# 2025-04-11 13:12:42,407 - INFO - ⏭️ Skipping 11670_10604_000010, features found in train or test.
# 2025-04-11 13:12:42,409 - INFO - ⏭️ Skipping 11670_10604_000011, features found in train or test.
# 2025-04-11 13:12:42,410 - INFO - ⏭️ Skipping 11670_10604_000012, features found in train or test.
# 2025-04-11 13:12:42,410 - INFO - ⏭️ Skipping 11670_10604_000013, features found in train or test.
# 2025-04-11 13:12:42,412 - INFO - ⏭️ Skipping 11670_10604_000014, features found in train or test.
# 2025-04-11 13:12:42,412 - INFO - ⏭️ Skipping 11670_10604_000015, features found in train or test.
# 2025-04-11 13:12:42,414 - INFO - ⏭️ Skipping 11670_10604_000016, features found in train or test.
# 2025-04-11 13:12:42,414 - INFO - ⏭️ Skipping 11670_10604_000017, features found in train or test.
# 2025-04-11 13:12:42,418 - INFO - ⏭️ Skipping 11670_10604_000018, features found in train or test.
# 2025-04-11 13:12:42,419 - INFO - ⏭️ Skipping 11670_10604_000019, features found in train or test.
# 2025-04-11 13:12:42,419 - INFO - ⏭️ Skipping 11670_10604_000020, features found in train or test.
# 2025-04-11 13:12:42,420 - INFO - ⏭️ Skipping 11670_10604_000021, features found in train or test.
# 2025-04-11 13:12:42,421 - INFO - ⏭️ Skipping 11670_10604_000022, features found in train or test.
# 2025-04-11 13:12:42,421 - INFO - ⏭️ Skipping 11670_10604_000023, features found in train or test.
# 2025-04-11 13:12:42,422 - INFO - ⏭️ Skipping 11670_10604_000024, features found in train or test.
# 2025-04-11 13:12:42,423 - INFO - ⏭️ Skipping 11670_10604_000025, features found in train or test.
# 2025-04-11 13:12:42,423 - INFO - ⏭️ Skipping 11670_10604_000026, features found in train or test.
# 2025-04-11 13:12:42,424 - INFO - ⏭️ Skipping 11670_10604_000027, features found in train or test.
# 2025-04-11 13:12:42,425 - INFO - ⏭️ Skipping 11670_10604_000028, features found in train or test.
# 2025-04-11 13:12:42,425 - INFO - ⏭️ Skipping 11670_10604_000029, features found in train or test.
# 2025-04-11 13:12:42,427 - INFO - ⏭️ Skipping 11670_10604_000030, features found in train or test.
# 2025-04-11 13:12:42,428 - INFO - ⏭️ Skipping 11670_10604_000031, features found in train or test.
# 2025-04-11 13:12:42,428 - INFO - ⏭️ Skipping 11670_10604_000032, features found in train or test.
# 2025-04-11 13:12:42,429 - INFO - ⏭️ Skipping 11670_10604_000033, features found in train or test.
# 2025-04-11 13:12:42,430 - INFO - ⏭️ Skipping 11670_10604_000034, features found in train or test.
# 2025-04-11 13:12:42,430 - INFO - ⏭️ Skipping 11670_10604_000035, features found in train or test.
# 2025-04-11 13:12:42,431 - INFO - ⏭️ Skipping 11670_10604_000036, features found in train or test.
# 2025-04-11 13:12:42,432 - INFO - ⏭️ Skipping 11670_10604_000037, features found in train or test.
# 2025-04-11 13:12:42,432 - INFO - ⏭️ Skipping 11670_10604_000038, features found in train or test.
# 2025-04-11 13:12:42,433 - INFO - ⏭️ Skipping 11670_10604_000039, features found in train or test.
# 2025-04-11 13:12:42,434 - INFO - ⏭️ Skipping 11670_10604_000040, features found in train or test.
# 2025-04-11 13:12:42,435 - INFO - ⏭️ Skipping 11670_10604_000041, features found in train or test.
# 2025-04-11 13:12:42,436 - INFO - ⏭️ Skipping 11670_10604_000042, features found in train or test.
# 2025-04-11 13:12:42,436 - INFO - ⏭️ Skipping 11670_10604_000043, features found in train or test.
# 2025-04-11 13:12:42,437 - INFO - ⏭️ Skipping 11670_10604_000044, features found in train or test.
# 2025-04-11 13:12:42,440 - INFO - ⏭️ Skipping 11670_10604_000045, features found in train or test.
# 2025-04-11 13:12:42,440 - INFO - ⏭️ Skipping 11670_10604_000046, features found in train or test.
# 2025-04-11 13:12:42,440 - INFO - ⏭️ Skipping 11670_10604_000047, features found in train or test.
# 2025-04-11 13:12:42,440 - INFO - ⏭️ Skipping 11670_10604_000048, features found in train or test.
# 2025-04-11 13:12:42,440 - INFO - ⏭️ Skipping 11670_10604_000049, features found in train or test.
# 2025-04-11 13:12:42,440 - INFO - ⏭️ Skipping 11670_10604_000050, features found in train or test.
# 2025-04-11 13:12:42,440 - INFO - ⏭️ Skipping 11670_10604_000051, features found in train or test.
# 2025-04-11 13:12:42,440 - INFO - ⏭️ Skipping 11670_10604_000052, features found in train or test.
# 2025-04-11 13:12:42,440 - INFO - ⏭️ Skipping 11670_10604_000053, features found in train or test.
# 2025-04-11 13:12:42,440 - INFO - ⏭️ Skipping 11670_10604_000054, features found in train or test.
# 2025-04-11 13:12:42,451 - INFO - ⏭️ Skipping 11670_10604_000055, features found in train or test.
# 2025-04-11 13:12:42,452 - INFO - ⏭️ Skipping 11670_10604_000056, features found in train or test.
# 2025-04-11 13:12:42,452 - INFO - ⏭️ Skipping 11670_10604_000057, features found in train or test.
# 2025-04-11 13:12:42,454 - INFO - ⏭️ Skipping 11670_10604_000058, features found in train or test.
# 2025-04-11 13:12:42,454 - INFO - ⏭️ Skipping 11670_10604_000059, features found in train or test.
# 2025-04-11 13:12:42,455 - INFO - ⏭️ Skipping 11670_10604_000060, features found in train or test.
# 2025-04-11 13:12:42,456 - INFO - ⏭️ Skipping 11670_10604_000061, features found in train or test.
# 2025-04-11 13:12:42,457 - INFO - ⏭️ Skipping 11670_10604_000062, features found in train or test.
# 2025-04-11 13:12:42,458 - INFO - ⏭️ Skipping 11670_10604_000063, features found in train or test.
# 2025-04-11 13:12:42,458 - INFO - ⏭️ Skipping 11670_10604_000064, features found in train or test.
# 2025-04-11 13:12:42,459 - INFO - ⏭️ Skipping 11670_10604_000065, features found in train or test.
# 2025-04-11 13:12:42,461 - INFO - ⏭️ Skipping 11670_10604_000066, features found in train or test.
# 2025-04-11 13:12:42,467 - INFO - ⏭️ Skipping 11670_10604_000067, features found in train or test.
# 2025-04-11 13:12:42,480 - INFO - ⏭️ Skipping 11670_10604_000068, features found in train or test.
# 2025-04-11 13:12:42,487 - INFO - ⏭️ Skipping 11670_10604_000069, features found in train or test.
# 2025-04-11 13:12:42,493 - INFO - ⏭️ Skipping 11670_10604_000070, features found in train or test.
# 2025-04-11 13:12:42,495 - INFO - ⏭️ Skipping 11670_10604_000071, features found in train or test.
# 2025-04-11 13:12:42,496 - INFO - ⏭️ Skipping 11670_10604_000072, features found in train or test.
# 2025-04-11 13:12:42,497 - INFO - ⏭️ Skipping 11670_10604_000073, features found in train or test.
# 2025-04-11 13:12:42,498 - INFO - ⏭️ Skipping 11670_10604_000074, features found in train or test.
# 2025-04-11 13:12:42,499 - INFO - ⏭️ Skipping 11670_10604_000075, features found in train or test.
# 2025-04-11 13:12:42,499 - INFO - ⏭️ Skipping 11670_10604_000076, features found in train or test.
# 2025-04-11 13:12:42,500 - INFO - ⏭️ Skipping 11670_10604_000077, features found in train or test.
# 2025-04-11 13:12:42,501 - INFO - ⏭️ Skipping 11670_10604_000078, features found in train or test.
# 2025-04-11 13:12:42,501 - INFO - ⏭️ Skipping 11670_10604_000079, features found in train or test.
# 2025-04-11 13:12:42,503 - INFO - ⏭️ Skipping 11670_10604_000080, features found in train or test.
# 2025-04-11 13:12:42,504 - INFO - ⏭️ Skipping 11670_10604_000081, features found in train or test.
# 2025-04-11 13:12:42,505 - INFO - ⏭️ Skipping 11670_10604_000082, features found in train or test.
# 2025-04-11 13:12:42,506 - INFO - ⏭️ Skipping 11670_10604_000083, features found in train or test.
# 2025-04-11 13:12:42,506 - INFO - ⏭️ Skipping 11670_10604_000084, features found in train or test.
# 2025-04-11 13:12:42,507 - INFO - ⏭️ Skipping 11670_10604_000085, features found in train or test.
# 2025-04-11 13:12:42,508 - INFO - ⏭️ Skipping 11670_10604_000086, features found in train or test.
# 2025-04-11 13:12:42,509 - INFO - ⏭️ Skipping 11670_10604_000087, features found in train or test.
# 2025-04-11 13:12:42,510 - INFO - ⏭️ Skipping 11670_10604_000088, features found in train or test.
# 2025-04-11 13:12:42,511 - INFO - ⏭️ Skipping 11670_10604_000089, features found in train or test.
# 2025-04-11 13:12:42,512 - INFO - ⏭️ Skipping 11670_10604_000090, features found in train or test.
# 2025-04-11 13:12:42,513 - INFO - ⏭️ Skipping 11670_10604_000091, features found in train or test.
# 2025-04-11 13:12:42,513 - INFO - ⏭️ Skipping 11670_10604_000092, features found in train or test.
# 2025-04-11 13:12:42,514 - INFO - ⏭️ Skipping 11670_10604_000093, features found in train or test.
# 2025-04-11 13:12:42,515 - INFO - ⏭️ Skipping 11670_10604_000094, features found in train or test.
# 2025-04-11 13:12:42,517 - INFO - ⏭️ Skipping 11670_10604_000095, features found in train or test.
# 2025-04-11 13:12:42,518 - INFO - ⏭️ Skipping 11670_10604_000096, features found in train or test.
# 2025-04-11 13:12:42,518 - INFO - ⏭️ Skipping 11670_10604_000097, features found in train or test.
# 2025-04-11 13:12:42,519 - INFO - ⏭️ Skipping 11670_10604_000098, features found in train or test.
# 2025-04-11 13:12:42,519 - INFO - ⏭️ Skipping 11670_10604_000099, features found in train or test.
# 2025-04-11 13:12:42,520 - INFO - ⏭️ Skipping 11670_10604_000100, features found in train or test.
# 2025-04-11 13:12:42,521 - INFO - ⏭️ Skipping 11670_10604_000101, features found in train or test.
# 2025-04-11 13:12:42,522 - INFO - ⏭️ Skipping 11670_10604_000102, features found in train or test.
# 2025-04-11 13:12:42,523 - INFO - ⏭️ Skipping 11670_10604_000103, features found in train or test.
# 2025-04-11 13:12:42,523 - INFO - ⏭️ Skipping 11670_10604_000104, features found in train or test.
# 2025-04-11 13:12:42,524 - INFO - ⏭️ Skipping 11670_10604_000105, features found in train or test.
# 2025-04-11 13:12:42,524 - INFO - ⏭️ Skipping 11670_10604_000106, features found in train or test.
# 2025-04-11 13:12:42,526 - INFO - ⏭️ Skipping 11670_10604_000107, features found in train or test.
# 2025-04-11 13:12:42,526 - INFO - ⏭️ Skipping 11670_10604_000108, features found in train or test.
# 2025-04-11 13:12:42,527 - INFO - ⏭️ Skipping 11670_10604_000109, features found in train or test.
# 2025-04-11 13:12:42,528 - INFO - ⏭️ Skipping 11670_10604_000110, features found in train or test.
# 2025-04-11 13:12:42,529 - INFO - ⏭️ Skipping 11670_10604_000111, features found in train or test.
# 2025-04-11 13:12:42,530 - INFO - ⏭️ Skipping 11670_10604_000112, features found in train or test.
# 2025-04-11 13:12:42,531 - INFO - ⏭️ Skipping 11670_10604_000113, features found in train or test.
# 2025-04-11 13:12:42,531 - INFO - ⏭️ Skipping 11670_10604_000114, features found in train or test.
# 2025-04-11 13:12:42,532 - INFO - ⏭️ Skipping 11670_10604_000115, features found in train or test.
# 2025-04-11 13:12:42,533 - INFO - ⏭️ Skipping 11670_10604_000116, features found in train or test.
# 2025-04-11 13:12:42,534 - INFO - ⏭️ Skipping 11670_10604_000117, features found in train or test.
# 2025-04-11 13:12:42,545 - INFO - ⏭️ Skipping 11670_10604_000118, features found in train or test.
# 2025-04-11 13:12:42,546 - INFO - ⏭️ Skipping 11670_10604_000119, features found in train or test.
# 2025-04-11 13:12:42,546 - INFO - ⏭️ Skipping 11670_10604_000120, features found in train or test.
# 2025-04-11 13:12:42,549 - INFO - ⏭️ Skipping 11670_10604_000121, features found in train or test.
# 2025-04-11 13:12:42,552 - INFO - ⏭️ Skipping 11670_10604_000122, features found in train or test.
# 2025-04-11 13:12:42,553 - INFO - ⏭️ Skipping 11670_10604_000123, features found in train or test.
# 2025-04-11 13:12:42,556 - INFO - ⏭️ Skipping 11670_10604_000124, features found in train or test.
# 2025-04-11 13:12:42,557 - INFO - ⏭️ Skipping 11670_10604_000125, features found in train or test.
# 2025-04-11 13:12:42,558 - INFO - ⏭️ Skipping 11670_10604_000126, features found in train or test.
# 2025-04-11 13:12:42,559 - INFO - ⏭️ Skipping 11670_10604_000127, features found in train or test.
# 2025-04-11 13:12:42,561 - INFO - ⏭️ Skipping 11670_10604_000128, features found in train or test.
# 2025-04-11 13:12:42,562 - INFO - ⏭️ Skipping 11670_10604_000129, features found in train or test.
# 2025-04-11 13:12:42,563 - INFO - ⏭️ Skipping 11670_10604_000130, features found in train or test.
# 2025-04-11 13:12:42,564 - INFO - ⏭️ Skipping 11670_10604_000131, features found in train or test.
# 2025-04-11 13:12:42,565 - INFO - ⏭️ Skipping 11670_10604_000132, features found in train or test.
# 2025-04-11 13:12:42,566 - INFO - ⏭️ Skipping 11670_10604_000133, features found in train or test.
# 2025-04-11 13:12:42,567 - INFO - ⏭️ Skipping 11670_10604_000134, features found in train or test.
# 2025-04-11 13:12:42,569 - INFO - ⏭️ Skipping 11670_10604_000135, features found in train or test.
# 2025-04-11 13:12:42,570 - INFO - ⏭️ Skipping 11670_10604_000136, features found in train or test.
# 2025-04-11 13:12:42,571 - INFO - ⏭️ Skipping 11670_10604_000137, features found in train or test.
# 2025-04-11 13:12:42,572 - INFO - ⏭️ Skipping 11670_10604_000138, features found in train or test.
# 2025-04-11 13:12:42,573 - INFO - ⏭️ Skipping 11670_10604_000139, features found in train or test.
# 2025-04-11 13:12:42,574 - INFO - ⏭️ Skipping 11670_10604_000140, features found in train or test.
# 2025-04-11 13:12:42,575 - INFO - ⏭️ Skipping 11670_10604_000141, features found in train or test.
# 2025-04-11 13:12:42,576 - INFO - ⏭️ Skipping 11670_10604_000142, features found in train or test.
# 2025-04-11 13:12:42,577 - INFO - ⏭️ Skipping 11670_10604_000143, features found in train or test.
# 2025-04-11 13:12:42,578 - INFO - ⏭️ Skipping 11670_10604_000144, features found in train or test.
# 2025-04-11 13:12:42,579 - INFO - ⏭️ Skipping 11670_10604_000145, features found in train or test.
# 2025-04-11 13:12:42,580 - INFO - ⏭️ Skipping 11670_10604_000146, features found in train or test.
# 2025-04-11 13:12:42,581 - INFO - ⏭️ Skipping 11670_10604_000147, features found in train or test.
# 2025-04-11 13:12:42,581 - INFO - ⏭️ Skipping 11670_10604_000148, features found in train or test.
# 2025-04-11 13:12:42,582 - INFO - ⏭️ Skipping 11670_10604_000149, features found in train or test.
# 2025-04-11 13:12:42,583 - INFO - ⏭️ Skipping 11670_10604_000150, features found in train or test.
# 2025-04-11 13:12:42,584 - INFO - ⏭️ Skipping 11670_10604_000151, features found in train or test.
# 2025-04-11 13:12:42,584 - INFO - ⏭️ Skipping 11670_10604_000152, features found in train or test.
# 2025-04-11 13:12:42,586 - INFO - ⏭️ Skipping 1227_567_000000, features found in train or test.
# 2025-04-11 13:12:42,586 - INFO - ⏭️ Skipping 1227_567_000001, features found in train or test.
# 2025-04-11 13:12:42,587 - INFO - ⏭️ Skipping 1227_567_000002, features found in train or test.
# 2025-04-11 13:12:42,588 - INFO - ⏭️ Skipping 1227_567_000003, features found in train or test.
# 2025-04-11 13:12:42,588 - INFO - ⏭️ Skipping 1227_567_000004, features found in train or test.
# 2025-04-11 13:12:42,589 - INFO - ⏭️ Skipping 1227_567_000005, features found in train or test.
# 2025-04-11 13:12:42,590 - INFO - ⏭️ Skipping 1227_567_000006, features found in train or test.
# 2025-04-11 13:12:42,591 - INFO - ⏭️ Skipping 1227_567_000007, features found in train or test.
# 2025-04-11 13:12:42,591 - INFO - ⏭️ Skipping 1227_567_000008, features found in train or test.
# 2025-04-11 13:12:42,592 - INFO - ⏭️ Skipping 1227_567_000009, features found in train or test.
# 2025-04-11 13:12:42,593 - INFO - ⏭️ Skipping 1227_567_000010, features found in train or test.
# 2025-04-11 13:12:42,594 - INFO - ⏭️ Skipping 1227_567_000011, features found in train or test.
# 2025-04-11 13:12:42,594 - INFO - ⏭️ Skipping 1227_567_000012, features found in train or test.
# 2025-04-11 13:12:42,595 - INFO - ⏭️ Skipping 1227_567_000013, features found in train or test.
# 2025-04-11 13:12:42,595 - INFO - ⏭️ Skipping 1227_567_000014, features found in train or test.
# 2025-04-11 13:12:42,596 - INFO - ⏭️ Skipping 1227_567_000015, features found in train or test.
# 2025-04-11 13:12:42,597 - INFO - ⏭️ Skipping 1227_567_000016, features found in train or test.
# 2025-04-11 13:12:42,598 - INFO - ⏭️ Skipping 1227_567_000017, features found in train or test.
# 2025-04-11 13:12:42,599 - INFO - ⏭️ Skipping 1227_567_000018, features found in train or test.
# 2025-04-11 13:12:42,600 - INFO - ⏭️ Skipping 1227_567_000019, features found in train or test.
# 2025-04-11 13:12:42,601 - INFO - ⏭️ Skipping 1227_567_000020, features found in train or test.
# 2025-04-11 13:12:42,603 - INFO - ⏭️ Skipping 1227_567_000021, features found in train or test.
# 2025-04-11 13:12:42,603 - INFO - ⏭️ Skipping 1227_567_000022, features found in train or test.
# 2025-04-11 13:12:42,604 - INFO - ⏭️ Skipping 1227_567_000023, features found in train or test.
# 2025-04-11 13:12:42,605 - INFO - ⏭️ Skipping 1227_567_000024, features found in train or test.
# 2025-04-11 13:12:42,606 - INFO - ⏭️ Skipping 1227_567_000025, features found in train or test.
# 2025-04-11 13:12:42,607 - INFO - ⏭️ Skipping 1227_567_000026, features found in train or test.
# 2025-04-11 13:12:42,607 - INFO - ⏭️ Skipping 1227_567_000027, features found in train or test.
# 2025-04-11 13:12:42,609 - INFO - ⏭️ Skipping 1227_567_000028, features found in train or test.
# 2025-04-11 13:12:42,609 - INFO - ⏭️ Skipping 1227_567_000029, features found in train or test.
# 2025-04-11 13:12:42,611 - INFO - ⏭️ Skipping 1227_567_000030, features found in train or test.
# 2025-04-11 13:12:42,613 - INFO - ⏭️ Skipping 1227_567_000031, features found in train or test.
# 2025-04-11 13:12:42,615 - INFO - ⏭️ Skipping 1227_567_000032, features found in train or test.
# 2025-04-11 13:12:42,615 - INFO - ⏭️ Skipping 1227_567_000033, features found in train or test.
# 2025-04-11 13:12:42,617 - INFO - ⏭️ Skipping 1227_567_000034, features found in train or test.
# 2025-04-11 13:12:42,618 - INFO - ⏭️ Skipping 1227_567_000035, features found in train or test.
# 2025-04-11 13:12:42,619 - INFO - ⏭️ Skipping 1227_567_000036, features found in train or test.
# 2025-04-11 13:12:42,620 - INFO - ⏭️ Skipping 1227_567_000037, features found in train or test.
# 2025-04-11 13:12:42,621 - INFO - ⏭️ Skipping 1227_567_000038, features found in train or test.
# 2025-04-11 13:12:42,622 - INFO - ⏭️ Skipping 1227_567_000039, features found in train or test.
# 2025-04-11 13:12:42,622 - INFO - ⏭️ Skipping 1227_567_000040, features found in train or test.
# 2025-04-11 13:12:42,623 - INFO - ⏭️ Skipping 1227_567_000041, features found in train or test.
# 2025-04-11 13:12:42,624 - INFO - ⏭️ Skipping 1227_567_000042, features found in train or test.
# 2025-04-11 13:12:42,625 - INFO - ⏭️ Skipping 1227_567_000043, features found in train or test.
# 2025-04-11 13:12:42,626 - INFO - ⏭️ Skipping 1227_567_000044, features found in train or test.
# 2025-04-11 13:12:42,626 - INFO - ⏭️ Skipping 1227_567_000045, features found in train or test.
# 2025-04-11 13:12:42,627 - INFO - ⏭️ Skipping 1227_567_000046, features found in train or test.
# 2025-04-11 13:12:42,628 - INFO - ⏭️ Skipping 1227_567_000047, features found in train or test.
# 2025-04-11 13:12:42,629 - INFO - ⏭️ Skipping 1227_567_000048, features found in train or test.
# 2025-04-11 13:12:42,630 - INFO - ⏭️ Skipping 1227_567_000049, features found in train or test.
# 2025-04-11 13:12:42,631 - INFO - ⏭️ Skipping 1227_567_000050, features found in train or test.
# 2025-04-11 13:12:42,632 - INFO - ⏭️ Skipping 1227_567_000051, features found in train or test.
# 2025-04-11 13:12:42,634 - INFO - ⏭️ Skipping 1227_567_000052, features found in train or test.
# 2025-04-11 13:12:42,635 - INFO - ⏭️ Skipping 1227_567_000053, features found in train or test.
# 2025-04-11 13:12:42,635 - INFO - ⏭️ Skipping 1227_567_000054, features found in train or test.
# 2025-04-11 13:12:42,637 - INFO - ⏭️ Skipping 1227_567_000055, features found in train or test.
# 2025-04-11 13:12:42,638 - INFO - ⏭️ Skipping 1227_567_000056, features found in train or test.
# 2025-04-11 13:12:42,638 - INFO - ⏭️ Skipping 1227_567_000057, features found in train or test.
# 2025-04-11 13:12:42,639 - INFO - ⏭️ Skipping 1227_567_000058, features found in train or test.
# 2025-04-11 13:12:42,640 - INFO - ⏭️ Skipping 1227_567_000059, features found in train or test.
# 2025-04-11 13:12:42,641 - INFO - ⏭️ Skipping 1227_567_000060, features found in train or test.
# 2025-04-11 13:12:42,642 - INFO - ⏭️ Skipping 1227_567_000061, features found in train or test.
# 2025-04-11 13:12:42,643 - INFO - ⏭️ Skipping 1227_567_000062, features found in train or test.
# 2025-04-11 13:12:42,645 - INFO - ⏭️ Skipping 1227_567_000063, features found in train or test.
# 2025-04-11 13:12:42,646 - INFO - ⏭️ Skipping 1227_567_000064, features found in train or test.
# 2025-04-11 13:12:42,647 - INFO - ⏭️ Skipping 1227_567_000065, features found in train or test.
# 2025-04-11 13:12:42,648 - INFO - ⏭️ Skipping 1227_567_000066, features found in train or test.
# 2025-04-11 13:12:42,648 - INFO - ⏭️ Skipping 1227_567_000067, features found in train or test.
# 2025-04-11 13:12:42,650 - INFO - ⏭️ Skipping 1227_567_000068, features found in train or test.
# 2025-04-11 13:12:42,650 - INFO - ⏭️ Skipping 1227_567_000069, features found in train or test.
# 2025-04-11 13:12:42,651 - INFO - ⏭️ Skipping 1227_567_000070, features found in train or test.
# 2025-04-11 13:12:42,652 - INFO - ⏭️ Skipping 1227_567_000071, features found in train or test.
# 2025-04-11 13:12:42,653 - INFO - ⏭️ Skipping 1227_567_000072, features found in train or test.
# 2025-04-11 13:12:42,654 - INFO - ⏭️ Skipping 1227_567_000073, features found in train or test.
# 2025-04-11 13:12:42,655 - INFO - ⏭️ Skipping 1227_567_000074, features found in train or test.
# 2025-04-11 13:12:42,656 - INFO - ⏭️ Skipping 1227_567_000075, features found in train or test.
# 2025-04-11 13:12:42,657 - INFO - ⏭️ Skipping 1227_567_000076, features found in train or test.
# 2025-04-11 13:12:42,658 - INFO - ⏭️ Skipping 1227_567_000077, features found in train or test.
# 2025-04-11 13:12:42,659 - INFO - ⏭️ Skipping 1227_567_000078, features found in train or test.
# 2025-04-11 13:12:42,660 - INFO - ⏭️ Skipping 1227_567_000079, features found in train or test.
# 2025-04-11 13:12:42,661 - INFO - ⏭️ Skipping 1227_567_000080, features found in train or test.
# 2025-04-11 13:12:42,661 - INFO - ⏭️ Skipping 1227_567_000081, features found in train or test.
# 2025-04-11 13:12:42,662 - INFO - ⏭️ Skipping 1227_567_000082, features found in train or test.
# 2025-04-11 13:12:42,663 - INFO - ⏭️ Skipping 1227_567_000083, features found in train or test.
# 2025-04-11 13:12:42,664 - INFO - ⏭️ Skipping 1227_567_000084, features found in train or test.
# 2025-04-11 13:12:42,665 - INFO - ⏭️ Skipping 1227_567_000085, features found in train or test.
# 2025-04-11 13:12:42,665 - INFO - ⏭️ Skipping 1227_567_000086, features found in train or test.
# 2025-04-11 13:12:42,666 - INFO - ⏭️ Skipping 1227_567_000087, features found in train or test.
# 2025-04-11 13:12:42,667 - INFO - ⏭️ Skipping 1227_567_000088, features found in train or test.
# 2025-04-11 13:12:42,668 - INFO - ⏭️ Skipping 1227_567_000089, features found in train or test.
# 2025-04-11 13:12:42,669 - INFO - ⏭️ Skipping 1227_567_000090, features found in train or test.
# 2025-04-11 13:12:42,669 - INFO - ⏭️ Skipping 1227_567_000091, features found in train or test.
# 2025-04-11 13:12:42,670 - INFO - ⏭️ Skipping 1227_567_000092, features found in train or test.
# 2025-04-11 13:12:42,670 - INFO - ⏭️ Skipping 1227_567_000093, features found in train or test.
# 2025-04-11 13:12:42,671 - INFO - ⏭️ Skipping 1227_567_000094, features found in train or test.
# 2025-04-11 13:12:42,672 - INFO - ⏭️ Skipping 1227_567_000095, features found in train or test.
# 2025-04-11 13:12:42,673 - INFO - ⏭️ Skipping 133_1378_000000, features found in train or test.
# 2025-04-11 13:12:42,674 - INFO - ⏭️ Skipping 133_1378_000001, features found in train or test.
# 2025-04-11 13:12:42,675 - INFO - ⏭️ Skipping 133_1378_000002, features found in train or test.
# 2025-04-11 13:12:42,675 - INFO - ⏭️ Skipping 133_1378_000003, features found in train or test.
# 2025-04-11 13:12:42,676 - INFO - ⏭️ Skipping 133_1378_000004, features found in train or test.
# 2025-04-11 13:12:42,677 - INFO - ⏭️ Skipping 133_1378_000005, features found in train or test.
# 2025-04-11 13:12:42,679 - INFO - ⏭️ Skipping 133_1378_000006, features found in train or test.
# 2025-04-11 13:12:42,679 - INFO - ⏭️ Skipping 133_1378_000007, features found in train or test.
# 2025-04-11 13:12:42,681 - INFO - ⏭️ Skipping 133_1378_000008, features found in train or test.
# 2025-04-11 13:12:42,681 - INFO - ⏭️ Skipping 133_1378_000009, features found in train or test.
# 2025-04-11 13:12:42,682 - INFO - ⏭️ Skipping 133_1378_000010, features found in train or test.
# 2025-04-11 13:12:42,683 - INFO - ⏭️ Skipping 133_1378_000011, features found in train or test.
# 2025-04-11 13:12:42,684 - INFO - ⏭️ Skipping 133_1378_000012, features found in train or test.
# 2025-04-11 13:12:42,684 - INFO - ⏭️ Skipping 133_1378_000013, features found in train or test.
# 2025-04-11 13:12:42,685 - INFO - ⏭️ Skipping 133_1378_000014, features found in train or test.
# 2025-04-11 13:12:42,686 - INFO - ⏭️ Skipping 133_1378_000015, features found in train or test.
# 2025-04-11 13:12:42,686 - INFO - ⏭️ Skipping 133_1378_000016, features found in train or test.
# 2025-04-11 13:12:42,687 - INFO - ⏭️ Skipping 133_1378_000017, features found in train or test.
# 2025-04-11 13:12:42,689 - INFO - ⏭️ Skipping 133_1378_000018, features found in train or test.
# 2025-04-11 13:12:42,690 - INFO - ⏭️ Skipping 133_1378_000019, features found in train or test.
# 2025-04-11 13:12:42,690 - INFO - ⏭️ Skipping 133_1378_000020, features found in train or test.
# 2025-04-11 13:12:42,692 - INFO - ⏭️ Skipping 133_1378_000021, features found in train or test.
# 2025-04-11 13:12:42,692 - INFO - ⏭️ Skipping 133_1378_000022, features found in train or test.
# 2025-04-11 13:12:42,693 - INFO - ⏭️ Skipping 133_1378_000023, features found in train or test.
# 2025-04-11 13:12:42,693 - INFO - ⏭️ Skipping 133_1378_000024, features found in train or test.
# 2025-04-11 13:12:42,693 - INFO - ⏭️ Skipping 133_1378_000025, features found in train or test.
# 2025-04-11 13:12:42,693 - INFO - ⏭️ Skipping 133_1378_000026, features found in train or test.
# 2025-04-11 13:12:42,693 - INFO - ⏭️ Skipping 133_1378_000027, features found in train or test.
# 2025-04-11 13:12:42,693 - INFO - ⏭️ Skipping 133_1378_000028, features found in train or test.
# 2025-04-11 13:12:42,701 - INFO - ⏭️ Skipping 133_1378_000029, features found in train or test.
# 2025-04-11 13:12:42,702 - INFO - ⏭️ Skipping 133_1378_000030, features found in train or test.
# 2025-04-11 13:12:42,703 - INFO - ⏭️ Skipping 133_1378_000031, features found in train or test.
# 2025-04-11 13:12:42,703 - INFO - ⏭️ Skipping 133_1378_000032, features found in train or test.
# 2025-04-11 13:12:42,704 - INFO - ⏭️ Skipping 133_1378_000033, features found in train or test.
# 2025-04-11 13:12:42,706 - INFO - ⏭️ Skipping 133_1378_000034, features found in train or test.
# 2025-04-11 13:12:42,707 - INFO - ⏭️ Skipping 133_1378_000035, features found in train or test.
# 2025-04-11 13:12:42,707 - INFO - ⏭️ Skipping 133_1378_000036, features found in train or test.
# 2025-04-11 13:12:42,709 - INFO - ⏭️ Skipping 133_1378_000037, features found in train or test.
# 2025-04-11 13:12:42,711 - INFO - ⏭️ Skipping 133_1378_000038, features found in train or test.
# 2025-04-11 13:12:42,712 - INFO - ⏭️ Skipping 133_1378_000039, features found in train or test.
# ...
# 2025-04-11 13:12:44,391 - INFO - ⏭️ Skipping 7331_6706_000148, features found in train or test.
# 2025-04-11 13:12:44,400 - INFO - ⏭️ Skipping 7331_6706_000149, features found in train or test.
# 2025-04-11 13:12:44,400 - INFO - ⏭️ Skipping 7331_6706_000150, features found in train or test.
# 2025-04-11 13:12:44,402 - INFO - ⏭️ Skipping 7331_6706_000151, features found in train or test.
# 2025-04-11 13:12:44,402 - INFO - ⏭️ Skipping 7331_6706_000152, features found in train or test.
# 2025-04-11 13:12:44,403 - INFO - ⏭️ Skipping 7331_6706_000153, features found in train or test.
# 2025-04-11 13:12:44,404 - INFO - ⏭️ Skipping 7331_6706_000154, features found in train or test.
# 2025-04-11 13:12:44,405 - INFO - ⏭️ Skipping 7331_6706_000155, features found in train or test.
# 2025-04-11 13:12:44,406 - INFO - ⏭️ Skipping 7331_6706_000156, features found in train or test.
# 2025-04-11 13:12:44,406 - INFO - ⏭️ Skipping 7331_6706_000157, features found in train or test.
# 2025-04-11 13:12:44,407 - INFO - ⏭️ Skipping 7331_6706_000158, features found in train or test.
# 2025-04-11 13:12:44,408 - INFO - ⏭️ Skipping 8630_7613_000000, features found in train or test.
# 2025-04-11 13:12:44,408 - INFO - ⏭️ Skipping 8630_7613_000001, features found in train or test.
# 2025-04-11 13:12:44,409 - INFO - ⏭️ Skipping 8630_7613_000002, features found in train or test.
# 2025-04-11 13:12:44,411 - INFO - ⏭️ Skipping 8630_7613_000003, features found in train or test.
# 2025-04-11 13:12:44,412 - INFO - ⏭️ Skipping 8630_7613_000004, features found in train or test.
# 2025-04-11 13:12:44,412 - INFO - ⏭️ Skipping 8630_7613_000005, features found in train or test.
# 2025-04-11 13:12:44,414 - INFO - ⏭️ Skipping 8630_7613_000006, features found in train or test.
# 2025-04-11 13:12:44,416 - INFO - ⏭️ Skipping 8630_7613_000007, features found in train or test.
# 2025-04-11 13:12:44,420 - INFO - ⏭️ Skipping 8630_7613_000008, features found in train or test.
# 2025-04-11 13:12:44,421 - INFO - ⏭️ Skipping 8630_7613_000009, features found in train or test.
# 2025-04-11 13:12:44,421 - INFO - ⏭️ Skipping 8630_7613_000010, features found in train or test.
# 2025-04-11 13:12:44,422 - INFO - ⏭️ Skipping 8630_7613_000011, features found in train or test.
# 2025-04-11 13:12:44,423 - INFO - ⏭️ Skipping 8630_7613_000012, features found in train or test.
# 2025-04-11 13:12:44,424 - INFO - ⏭️ Skipping 8630_7613_000013, features found in train or test.
# 2025-04-11 13:12:44,424 - INFO - ⏭️ Skipping 8630_7613_000014, features found in train or test.
# 2025-04-11 13:12:44,425 - INFO - ⏭️ Skipping 8630_7613_000015, features found in train or test.
# 2025-04-11 13:12:44,426 - INFO - ⏭️ Skipping 8630_7613_000016, features found in train or test.
# 2025-04-11 13:12:44,427 - INFO - ⏭️ Skipping 8630_7613_000017, features found in train or test.
# 2025-04-11 13:12:44,428 - INFO - ⏭️ Skipping 8630_7613_000018, features found in train or test.
# 2025-04-11 13:12:44,429 - INFO - ⏭️ Skipping 8630_7613_000019, features found in train or test.
# 2025-04-11 13:12:44,430 - INFO - ⏭️ Skipping 8630_7613_000020, features found in train or test.
# 2025-04-11 13:12:44,431 - INFO - ⏭️ Skipping 8630_7613_000021, features found in train or test.
# 2025-04-11 13:12:44,431 - INFO - ⏭️ Skipping 8630_7613_000022, features found in train or test.
# 2025-04-11 13:12:44,433 - INFO - ⏭️ Skipping 8630_7613_000023, features found in train or test.
# 2025-04-11 13:12:44,434 - INFO - ⏭️ Skipping 8630_7613_000024, features found in train or test.
# 2025-04-11 13:12:44,435 - INFO - ⏭️ Skipping 8630_7613_000025, features found in train or test.
# 2025-04-11 13:12:44,436 - INFO - ⏭️ Skipping 8630_7613_000026, features found in train or test.
# 2025-04-11 13:12:44,437 - INFO - ⏭️ Skipping 8630_7613_000027, features found in train or test.
# 2025-04-11 13:12:44,438 - INFO - ⏭️ Skipping 8630_7613_000028, features found in train or test.
# 2025-04-11 13:12:44,439 - INFO - ⏭️ Skipping 8630_7613_000029, features found in train or test.
# 2025-04-11 13:12:44,440 - INFO - ⏭️ Skipping 8630_7613_000030, features found in train or test.
# 2025-04-11 13:12:44,440 - INFO - ⏭️ Skipping 8630_7613_000031, features found in train or test.
# 2025-04-11 13:12:44,441 - INFO - ⏭️ Skipping 8630_7613_000032, features found in train or test.
# 2025-04-11 13:12:44,442 - INFO - ⏭️ Skipping 8630_7613_000033, features found in train or test.
# 2025-04-11 13:12:44,442 - INFO - ⏭️ Skipping 8630_7613_000034, features found in train or test.
# 2025-04-11 13:12:44,443 - INFO - ⏭️ Skipping 8630_7613_000035, features found in train or test.
# 2025-04-11 13:12:44,444 - INFO - ⏭️ Skipping 8630_7613_000036, features found in train or test.
# 2025-04-11 13:12:44,445 - INFO - ⏭️ Skipping 8630_7613_000037, features found in train or test.
# 2025-04-11 13:12:44,446 - INFO - ⏭️ Skipping 8630_7613_000038, features found in train or test.
# 2025-04-11 13:12:44,447 - INFO - ⏭️ Skipping 8630_7613_000039, features found in train or test.
# 2025-04-11 13:12:44,448 - INFO - ⏭️ Skipping 8630_7613_000040, features found in train or test.
# 2025-04-11 13:12:44,448 - INFO - ⏭️ Skipping 8630_7613_000041, features found in train or test.
# 2025-04-11 13:12:44,449 - INFO - ⏭️ Skipping 8630_7613_000042, features found in train or test.
# 2025-04-11 13:12:44,450 - INFO - ⏭️ Skipping 8630_7613_000043, features found in train or test.
# 2025-04-11 13:12:44,451 - INFO - ⏭️ Skipping 8630_7613_000044, features found in train or test.
# 2025-04-11 13:12:44,451 - INFO - ⏭️ Skipping 8630_7613_000045, features found in train or test.
# 2025-04-11 13:12:44,451 - INFO - ⏭️ Skipping 8630_7613_000046, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000047, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000048, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000049, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000050, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000051, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000052, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000053, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000054, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000055, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000056, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000057, features found in train or test.
# 2025-04-11 13:12:44,454 - INFO - ⏭️ Skipping 8630_7613_000058, features found in train or test.
# 2025-04-11 13:12:44,464 - INFO - ⏭️ Skipping 8630_7613_000059, features found in train or test.
# 2025-04-11 13:12:44,464 - INFO - ⏭️ Skipping 8630_7613_000060, features found in train or test.
# 2025-04-11 13:12:44,466 - INFO - ⏭️ Skipping 8630_7613_000061, features found in train or test.
# 2025-04-11 13:12:44,467 - INFO - ⏭️ Skipping 8630_7613_000062, features found in train or test.
# 2025-04-11 13:12:44,468 - INFO - ⏭️ Skipping 8630_7613_000063, features found in train or test.
# 2025-04-11 13:12:44,468 - INFO - ⏭️ Skipping 8630_7613_000064, features found in train or test.
# 2025-04-11 13:12:44,468 - INFO - ⏭️ Skipping 8630_7613_000065, features found in train or test.
# 2025-04-11 13:12:44,468 - INFO - ⏭️ Skipping 8630_7613_000066, features found in train or test.
# 2025-04-11 13:12:44,468 - INFO - ⏭️ Skipping 8630_7613_000067, features found in train or test.
# 2025-04-11 13:12:44,468 - INFO - ⏭️ Skipping 8630_7613_000068, features found in train or test.
# 2025-04-11 13:12:44,468 - INFO - ⏭️ Skipping 8630_7613_000069, features found in train or test.
# 2025-04-11 13:12:44,474 - INFO - ⏭️ Skipping 8630_7613_000070, features found in train or test.
# 2025-04-11 13:12:44,475 - INFO - ⏭️ Skipping 8630_7613_000071, features found in train or test.
# 2025-04-11 13:12:44,476 - INFO - ⏭️ Skipping 8630_7613_000072, features found in train or test.
# 2025-04-11 13:12:44,477 - INFO - ⏭️ Skipping 8630_7613_000073, features found in train or test.
# 2025-04-11 13:12:44,478 - INFO - ⏭️ Skipping 8630_7613_000074, features found in train or test.
# 2025-04-11 13:12:44,478 - INFO - ⏭️ Skipping 8630_7613_000075, features found in train or test.
# 2025-04-11 13:12:44,479 - INFO - ⏭️ Skipping 8630_7613_000076, features found in train or test.
# 2025-04-11 13:12:44,480 - INFO - ⏭️ Skipping 8630_7613_000077, features found in train or test.
# 2025-04-11 13:12:44,481 - INFO - ⏭️ Skipping 8630_7613_000078, features found in train or test.
# 2025-04-11 13:12:44,482 - INFO - ⏭️ Skipping 8630_7613_000079, features found in train or test.
# 2025-04-11 13:12:44,483 - INFO - ⏭️ Skipping 8630_7613_000080, features found in train or test.
# 2025-04-11 13:12:44,484 - INFO - ⏭️ Skipping 8630_7613_000081, features found in train or test.
# 2025-04-11 13:12:44,485 - INFO - ⏭️ Skipping 8630_7613_000082, features found in train or test.
# 2025-04-11 13:12:44,485 - INFO - ⏭️ Skipping 8630_7613_000083, features found in train or test.
# 2025-04-11 13:12:44,485 - INFO - ⏭️ Skipping 8630_7613_000084, features found in train or test.
# 2025-04-11 13:12:44,485 - INFO - ⏭️ Skipping 8630_7613_000085, features found in train or test.
# 2025-04-11 13:12:44,485 - INFO - ⏭️ Skipping 8630_7613_000086, features found in train or test.
# 2025-04-11 13:12:44,485 - INFO - ⏭️ Skipping 8630_7613_000087, features found in train or test.
# 2025-04-11 13:12:44,491 - INFO - ⏭️ Skipping 8630_7613_000088, features found in train or test.
# 2025-04-11 13:12:44,491 - INFO - ⏭️ Skipping 8630_7613_000089, features found in train or test.
# 2025-04-11 13:12:44,491 - INFO - ⏭️ Skipping 8630_7613_000090, features found in train or test.
# 2025-04-11 13:12:44,491 - INFO - ⏭️ Skipping 8630_7613_000091, features found in train or test.
# 2025-04-11 13:12:44,491 - INFO - ⏭️ Skipping 8630_7613_000092, features found in train or test.
# 2025-04-11 13:12:44,495 - INFO - ⏭️ Skipping 8630_7613_000093, features found in train or test.
# 2025-04-11 13:12:44,495 - INFO - ⏭️ Skipping 8630_7613_000094, features found in train or test.
# 2025-04-11 13:12:44,495 - INFO - ⏭️ Skipping 8630_7613_000095, features found in train or test.
# 2025-04-11 13:12:44,497 - INFO - ⏭️ Skipping 8630_7613_000096, features found in train or test.
# 2025-04-11 13:12:44,497 - INFO - ⏭️ Skipping 8630_7613_000097, features found in train or test.
# 2025-04-11 13:12:44,497 - INFO - ⏭️ Skipping 8630_7613_000098, features found in train or test.
# 2025-04-11 13:12:44,499 - INFO - ⏭️ Skipping 8630_7613_000099, features found in train or test.
# 2025-04-11 13:12:44,500 - INFO - ⏭️ Skipping 8630_7613_000100, features found in train or test.
# 2025-04-11 13:12:44,501 - INFO - ⏭️ Skipping 8630_7613_000101, features found in train or test.
# 2025-04-11 13:12:44,502 - INFO - ⏭️ Skipping 8630_7613_000102, features found in train or test.
# 2025-04-11 13:12:44,503 - INFO - ⏭️ Skipping 8630_7613_000103, features found in train or test.
# 2025-04-11 13:12:44,504 - INFO - ⏭️ Skipping 8630_7613_000104, features found in train or test.
# 2025-04-11 13:12:44,506 - INFO - ⏭️ Skipping 8630_7613_000105, features found in train or test.
# 2025-04-11 13:12:44,507 - INFO - ⏭️ Skipping 8630_7613_000106, features found in train or test.
# 2025-04-11 13:12:44,507 - INFO - ⏭️ Skipping 8630_7613_000107, features found in train or test.
# 2025-04-11 13:12:44,508 - INFO - ⏭️ Skipping 8630_7613_000108, features found in train or test.
# 2025-04-11 13:12:44,509 - INFO - ⏭️ Skipping 8630_7613_000109, features found in train or test.
# 2025-04-11 13:12:44,510 - INFO - ⏭️ Skipping 8630_7613_000110, features found in train or test.
# 2025-04-11 13:12:44,511 - INFO - ⏭️ Skipping 8630_7613_000111, features found in train or test.
# 2025-04-11 13:12:44,512 - INFO - ⏭️ Skipping 8630_7613_000112, features found in train or test.
# 2025-04-11 13:12:44,513 - INFO - ⏭️ Skipping 8630_7613_000113, features found in train or test.
# 2025-04-11 13:12:44,514 - INFO - ⏭️ Skipping 8630_7613_000114, features found in train or test.
# 2025-04-11 13:12:44,514 - INFO - ⏭️ Skipping 8630_7613_000115, features found in train or test.
# 2025-04-11 13:12:44,515 - INFO - ⏭️ Skipping 8630_7613_000116, features found in train or test.
# 2025-04-11 13:12:44,516 - INFO - ⏭️ Skipping 8630_7613_000117, features found in train or test.
# 2025-04-11 13:12:44,517 - INFO - ⏭️ Skipping 8630_7613_000118, features found in train or test.
# 2025-04-11 13:12:44,518 - INFO - ⏭️ Skipping 8630_7613_000119, features found in train or test.
# 2025-04-11 13:12:44,518 - INFO - ⏭️ Skipping 8630_7613_000120, features found in train or test.
# 2025-04-11 13:12:44,519 - INFO - ⏭️ Skipping 8630_7613_000121, features found in train or test.
# 2025-04-11 13:12:44,520 - INFO - ⏭️ Skipping 8630_7613_000122, features found in train or test.
# 2025-04-11 13:12:44,521 - INFO - ⏭️ Skipping 8630_7613_000123, features found in train or test.
# 2025-04-11 13:12:44,522 - INFO - ⏭️ Skipping 8630_7613_000124, features found in train or test.
# 2025-04-11 13:12:44,523 - INFO - ⏭️ Skipping 8630_7613_000125, features found in train or test.
# 2025-04-11 13:12:44,523 - INFO - ⏭️ Skipping 8630_7613_000126, features found in train or test.
# 2025-04-11 13:12:44,524 - INFO - ⏭️ Skipping 8630_7613_000127, features found in train or test.
# 2025-04-11 13:12:44,525 - INFO - ⏭️ Skipping 8630_7613_000128, features found in train or test.
# 2025-04-11 13:12:44,526 - INFO - ⏭️ Skipping 8630_7613_000129, features found in train or test.
# 2025-04-11 13:12:44,527 - INFO - ⏭️ Skipping 8630_7613_000130, features found in train or test.
# 2025-04-11 13:12:44,527 - INFO - ⏭️ Skipping 8630_7613_000131, features found in train or test.
# 2025-04-11 13:12:44,528 - INFO - ⏭️ Skipping 8630_7613_000132, features found in train or test.
# 2025-04-11 13:12:44,529 - INFO - ⏭️ Skipping 8630_7613_000133, features found in train or test.
# 2025-04-11 13:12:44,530 - INFO - ⏭️ Skipping 8630_7613_000134, features found in train or test.
# 2025-04-11 13:12:44,531 - INFO - ⏭️ Skipping 8630_7613_000135, features found in train or test.
# 2025-04-11 13:12:44,531 - INFO - ⏭️ Skipping 8630_7613_000136, features found in train or test.
# 2025-04-11 13:12:44,532 - INFO - ⏭️ Skipping 8630_7613_000137, features found in train or test.
# 2025-04-11 13:12:44,533 - INFO - ⏭️ Skipping 8630_7613_000138, features found in train or test.
# 2025-04-11 13:12:44,534 - INFO - ⏭️ Skipping 8630_7613_000139, features found in train or test.
# 2025-04-11 13:12:44,535 - INFO - ⏭️ Skipping 8630_7613_000140, features found in train or test.
# 2025-04-11 13:12:44,536 - INFO - ⏭️ Skipping 8630_7613_000141, features found in train or test.
# 2025-04-11 13:12:44,537 - INFO - ⏭️ Skipping 8630_7613_000142, features found in train or test.
# 2025-04-11 13:12:44,538 - INFO - ⏭️ Skipping 8630_7613_000143, features found in train or test.
# 2025-04-11 13:12:44,539 - INFO - ⏭️ Skipping 8630_7613_000144, features found in train or test.
# 2025-04-11 13:12:44,539 - INFO - ⏭️ Skipping 8630_7613_000145, features found in train or test.
# 2025-04-11 13:12:44,539 - INFO - ⏭️ Skipping 8630_7613_000146, features found in train or test.
# 2025-04-11 13:12:44,539 - INFO - ⏭️ Skipping 8630_7613_000147, features found in train or test.
# 2025-04-11 13:12:44,539 - INFO - ⏭️ Skipping 8630_7613_000148, features found in train or test.
# 2025-04-11 13:12:44,547 - INFO - 📢 Processing 1 new audio files...
# 2025-04-11 13:12:46,942 - WARNING - ⚠ No transcript found for LearningEnglishConversations-20250311-TheEnglishWeSpeakCanDoAttitude.
# 2025-04-11 13:12:47,549 - INFO - ✅ Processed LearningEnglishConversations-20250311-TheEnglishWeSpeakCanDoAttitude: MFCC, Mel, Chroma
# 🔄 Processing new audio: 100%|██████████| 1/1 [00:02<00:00,  3.00s/it]
# 2025-04-11 13:12:47,630 - WARNING - ⚠ Not enough new complete feature sets to split (found 0).
# 2025-04-11 13:12:47,631 - INFO - ✅ Feature extraction and data splitting for new files complete.

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tqdm import tqdm
import logging
import librosa  # Make sure you have librosa installed: pip install librosa

logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# --- Configuration ---
FEATURES_FOLDER = r"C:\ASR\features"
SAMPLE_RATE = 16000
N_MFCC = 13  # Should match your extraction
N_MELS = 128 # Should match your extraction
N_CHROMA = 12 # Chroma features
TIME_STEPS = 128 # Adjust based on your desired input length
BATCH_SIZE = 32
EPOCHS = 30
VALIDATION_SPLIT = 0.2
RANDOM_STATE = 42
PAD_TOKEN = "[PAD]"
NUM_PREDICTIONS_TO_SHOW = 5

# --- Helper Functions ---
def load_concatenated_features_and_transcripts(features_folder, time_steps, pad_token=PAD_TOKEN):
    """Loads concatenated features and phoneme transcripts with padding."""
    X = []
    y = []
    phoneme_to_int = {pad_token: 0}  # Start with a padding token
    int_to_phoneme = {0: pad_token}
    phoneme_count = 1  # Start counting from 1

    train_folder = os.path.join(features_folder, "train")
    if not os.path.exists(train_folder):
        logging.error(f"Train folder not found at: {train_folder}")
        return None, None, None, None

    for base_name_dir in tqdm(os.listdir(train_folder), desc="Loading Training Data"):
        base_name_path = os.path.join(train_folder, base_name_dir)
        if os.path.isdir(base_name_path):
            mfcc_path = os.path.join(base_name_path, "mfcc.npy")
            mel_path = os.path.join(base_name_path, "mel.npy")
            chroma_path = os.path.join(base_name_path, "chroma.npy")
            phonemes_path = os.path.join(base_name_path, "phonemes.npy")

            if os.path.exists(mfcc_path) and os.path.exists(mel_path) and os.path.exists(chroma_path) and os.path.exists(phonemes_path):
                try:
                    mfcc = np.load(mfcc_path)
                    mel = np.load(mel_path)
                    chroma = np.load(chroma_path)
                    phonemes = np.load(phonemes_path, allow_pickle=True)

                    features = np.concatenate((mfcc, mel, chroma), axis=1)

                    if len(features) > 0 and len(phonemes) > 0:
                        # Pad features
                        if len(features) < time_steps:
                            padding_len = time_steps - len(features)
                            features = np.pad(features, ((0, padding_len), (0, 0)), 'constant')
                        else:
                            features = features[:time_steps]

                        X.append(features)

                        # Pad phonemes
                        int_sequence = []
                        for phoneme in phonemes:
                            if phoneme not in phoneme_to_int:
                                phoneme_to_int[phoneme] = phoneme_count
                                int_to_phoneme[phoneme_count] = phoneme
                                phoneme_count += 1
                            int_sequence.append(phoneme_to_int[phoneme])

                        if len(int_sequence) < time_steps:
                            padding_len = time_steps - len(int_sequence)
                            int_sequence = int_sequence + [phoneme_to_int[pad_token]] * padding_len
                        else:
                            int_sequence = int_sequence[:time_steps]

                        y.append(np.array(int_sequence))

                except Exception as e:
                    logging.error(f"Error loading data for {base_name_dir}: {e}")

    X = np.array(X)
    y = np.array(y)
    return X, y, phoneme_to_int, int_to_phoneme

def create_model(input_shape, num_phonemes):
    """Creates an RNN model for phoneme prediction with concatenated features."""
    model = models.Sequential([
        layers.LSTM(128, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(128, return_sequences=True),
        layers.Dropout(0.2),
        layers.TimeDistributed(layers.Dense(num_phonemes, activation='softmax'))
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

def evaluate_model(model, features_folder, time_steps, phoneme_to_int, int_to_phoneme, pad_token=PAD_TOKEN, num_predictions_to_show=NUM_PREDICTIONS_TO_SHOW):
    """Evaluates the trained model on the test set with concatenated features and padding,
       and shows some predicted vs. true phoneme sequences along with raw predictions."""
    test_folder = os.path.join(features_folder, "test")
    if not os.path.exists(test_folder):
        logging.warning(f"Test folder not found at: {test_folder}")
        return

    test_X = []
    test_y_int = []
    file_names = []  # To keep track of the audio files

    for base_name_dir in tqdm(os.listdir(test_folder), desc="Loading Test Data"):
        base_name_path = os.path.join(test_folder, base_name_dir)
        if os.path.isdir(base_name_path):
            mfcc_path = os.path.join(base_name_path, "mfcc.npy")
            mel_path = os.path.join(base_name_path, "mel.npy")
            chroma_path = os.path.join(base_name_path, "chroma.npy")
            phonemes_path = os.path.join(base_name_path, "phonemes.npy")

            if os.path.exists(mfcc_path) and os.path.exists(mel_path) and os.path.exists(chroma_path) and os.path.exists(phonemes_path):
                try:
                    mfcc = np.load(mfcc_path)
                    mel = np.load(mel_path)
                    chroma = np.load(chroma_path)
                    phonemes = np.load(phonemes_path, allow_pickle=True)

                    features = np.concatenate((mfcc, mel, chroma), axis=1)

                    if len(features) > 0 and len(phonemes) > 0:
                        # Pad features
                        if len(features) < time_steps:
                            padding_len = time_steps - len(features)
                            features = np.pad(features, ((0, padding_len), (0, 0)), 'constant')
                        else:
                            features = features[:time_steps]

                        test_X.append(features)

                        # Pad phonemes
                        int_sequence = [phoneme_to_int.get(p, phoneme_to_int.get(pad_token, -1)) for p in phonemes]
                        if all(i != -1 for i in int_sequence):
                            if len(int_sequence) < time_steps:
                                padding_len = time_steps - len(int_sequence)
                                int_sequence = int_sequence + [phoneme_to_int[pad_token]] * padding_len
                            else:
                                int_sequence = int_sequence[:time_steps]
                            test_y_int.append(np.array(int_sequence))
                            file_names.append(base_name_dir)  # Store the file name
                        else:
                            logging.warning(f"Skipping {base_name_dir} test data due to unknown phonemes.")

                except Exception as e:
                    logging.error(f"Error loading test data for {base_name_dir}: {e}")

    if not test_X:
        logging.warning("No valid test data found.")
        return

    test_X = np.array(test_X)
    test_y_int = np.array(test_y_int)

    if test_X.shape[0] != test_y_int.shape[0]:
        logging.error("Number of test features and labels do not match.")
        return

    loss, accuracy = model.evaluate(test_X, np.expand_dims(test_y_int, -1), verbose=0)
    logging.info(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")

    # Show some predictions and raw output
    num_samples = min(len(test_X), num_predictions_to_show)
    for i in range(num_samples):
        sample_features = np.expand_dims(test_X[i], axis=0)
        true_indices = test_y_int[i]
        predictions_raw = model.predict(sample_features)
        predicted_indices = np.argmax(predictions_raw, axis=-1)[0]

        true_phonemes = [int_to_phoneme.get(idx, '[UNK]') for idx in true_indices if idx != 0]
        predicted_phonemes = [int_to_phoneme.get(idx, '[UNK]') for idx in predicted_indices if idx != 0]

        logging.info(f"\n--- Prediction for: {file_names[i]} ---")
        logging.info(f"True Phonemes:    {true_phonemes}")
        logging.info(f"Predicted Phonemes: {predicted_phonemes}")
        logging.info(f"Raw Predictions (first time step):\n{predictions_raw[0][0]}") # Print probabilities for the first time step

def predict_phonemes(model, audio_path, time_steps, phoneme_to_int, int_to_phoneme, sample_rate=16000, n_mfcc=13, n_mels=128, n_chroma=12, pad_token=PAD_TOKEN):
    """Predicts phonemes for a given audio file with concatenated features and padding."""
    try:
        y, sr = librosa.load(audio_path, sr=sample_rate)
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc).T
        mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels).T
        chroma = librosa.feature.chroma_stft(y=y, sr=sr).T

        features = np.concatenate((mfccs, mel, chroma), axis=1)

        if len(features) > 0:
            # Pad features
            if len(features) < time_steps:
                padding_len = time_steps - len(features)
                input_features = np.pad(features, ((0, padding_len), (0, 0)), 'constant')
            else:
                input_features = features[:time_steps]
            input_features = np.expand_dims(input_features, axis=0)  # Add batch dimension

            predictions = model.predict(input_features)
            predicted_indices = np.argmax(predictions, axis=-1)[0]
            predicted_phonemes = [int_to_phoneme.get(idx, '[UNK]') for idx in predicted_indices if idx != 0] # Exclude padding token
            return predicted_phonemes
        else:
            logging.warning("Input audio resulted in empty feature array.")
            return []

    except Exception as e:
        logging.error(f"Error during prediction: {e}")
        return []

# --- Main Execution ---
if __name__ == "__main__":
    # Load concatenated features and transcripts with padding
    X, y, phoneme_to_int, int_to_phoneme = load_concatenated_features_and_transcripts(FEATURES_FOLDER, TIME_STEPS)

    if X is None or y is None:
        logging.error("Failed to load training data. Exiting.")
        exit()

    # Get the total number of features after concatenation
    num_features = X.shape[2]
    num_phonemes = len(phoneme_to_int)
    logging.info(f"Number of concatenated features per time step: {num_features}")
    logging.info(f"Number of unique phonemes (including padding): {num_phonemes}")
    logging.info(f"Training data shape (features): {X.shape}")
    logging.info(f"Training data shape (labels): {y.shape}")

    # Create the model with the updated input shape
    input_shape = (TIME_STEPS, num_features)
    model = create_model(input_shape, num_phonemes)
    model.summary()

    # Train the model
    model.fit(X, np.expand_dims(y, -1),  # Expand labels for sparse categorical crossentropy
              epochs=EPOCHS,
              batch_size=BATCH_SIZE,
              validation_split=VALIDATION_SPLIT,
              shuffle=True,
              callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)])

    # Evaluate the model on the test set and show predictions with raw output
    evaluate_model(model, FEATURES_FOLDER, TIME_STEPS, phoneme_to_int, int_to_phoneme)

    # Example prediction on a new audio file
    example_audio_path = r"C:\ASR\converted_audio\your_audio_file.wav" # Replace with a real path
    if os.path.exists(example_audio_path):
        predicted_phonemes = predict_phonemes(model, example_audio_path, TIME_STEPS, phoneme_to_int, int_to_phoneme)
        logging.info(f"\nPredicted phonemes for {os.path.basename(example_audio_path)}: {predicted_phonemes}")
    else:
        logging.warning(f"Example audio file not found at: {example_audio_path}")

    # Save the trained model and vocabulary
    model.save(os.path.join(FEATURES_FOLDER, "phoneme_predictor_model_concat_padded.h5"))
    np.save(os.path.join(FEATURES_FOLDER, "phoneme_to_int_concat_padded.npy"), phoneme_to_int)
    np.save(os.path.join(FEATURES_FOLDER, "int_to_phoneme_concat_padded.npy"), int_to_phoneme)
    logging.info("✅ Model and vocabulary saved (concatenated features with padding).")
# Out:
# Loading Training Data: 100%|██████████| 1633/1633 [00:30<00:00, 54.19it/s]
# 2025-04-11 13:15:44,539 - INFO - Number of concatenated features per time step: 153
# 2025-04-11 13:15:44,550 - INFO - Number of unique phonemes (including padding): 9409
# 2025-04-11 13:15:44,550 - INFO - Training data shape (features): (1633, 128, 153)
# 2025-04-11 13:15:44,552 - INFO - Training data shape (labels): (1633, 128)
# C:\Users\ACER\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128, 128)       │       144,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128, 128)       │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 128, 9409)      │     1,213,761 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,489,729 (5.68 MB)
#  Trainable params: 1,489,729 (5.68 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.6301 - loss: 7.3016 - val_accuracy: 0.7471 - val_loss: 2.3964
# Epoch 2/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.7083 - loss: 2.5627 - val_accuracy: 0.7471 - val_loss: 2.3993
# Epoch 3/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.7089 - loss: 2.4917 - val_accuracy: 0.7471 - val_loss: 2.2855
# Epoch 4/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.7134 - loss: 2.2973 - val_accuracy: 0.7471 - val_loss: 2.1384
# Epoch 5/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.7116 - loss: 2.1592 - val_accuracy: 0.7471 - val_loss: 2.0569
# Epoch 6/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.7022 - loss: 2.1628 - val_accuracy: 0.7471 - val_loss: 2.0327
# Epoch 7/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.7135 - loss: 2.0580 - val_accuracy: 0.7499 - val_loss: 2.1385
# Epoch 8/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.7158 - loss: 2.0636 - val_accuracy: 0.7505 - val_loss: 2.0627
# Epoch 9/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.7138 - loss: 2.0681 - val_accuracy: 0.7506 - val_loss: 2.0434
# Epoch 10/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.7162 - loss: 2.0571 - val_accuracy: 0.7526 - val_loss: 2.0498
# Epoch 11/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.7159 - loss: 2.0603 - val_accuracy: 0.7519 - val_loss: 2.0868
# Loading Test Data: 100%|██████████| 409/409 [00:11<00:00, 35.60it/s]
# 2025-04-11 13:30:37,112 - INFO - Test Loss: 1.8596, Test Accuracy: 0.7410
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 2025-04-11 13:30:38,276 - INFO -
# --- Prediction for: 10367_10282_000010 ---
# 2025-04-11 13:30:38,276 - INFO - True Phonemes:    ['ˈi', 'sˌuβiɾˈa', 'kwˈal', 'ɾɾenwˈeβo', 'delˈante', 'dˈe', 'ˈel', 'ˈi', 'kˈomo', 'dˈe', 'tjˈeɾɾa', 'sˈeka', 'nˈo', 'ˈaɪ', 'pˌaɾeθˈeɾ', 'ˈen', 'ˈel', 'nˈi', 'ˌeɾmosˈuɾa', 'bˈeɾlo', 'ˈemos', 'mˈas', 'sˈin', 'pˈaɾa', 'kˈe', 'lˈe']
# 2025-04-11 13:30:38,276 - INFO - Predicted Phonemes: []
# 2025-04-11 13:30:38,284 - INFO - Raw Predictions (first time step):
# [6.3762553e-03 5.2236430e-03 7.1334979e-04 ... 3.2413318e-05 3.3087355e-05
#  3.6499936e-05]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 2025-04-11 13:30:38,372 - INFO -
# --- Prediction for: 10367_10282_000011 ---
# 2025-04-11 13:30:38,372 - INFO - True Phonemes:    ['ˈi', 'seɾˈa', 'ˈa', 'xˌeoβˈa', 'pˈoɾ', 'nˈombɾe', 'pˈoɾ', 'seɲˈal', 'etˈeɾna', 'kˈe', 'nˈunka', 'seɾˈa', 'ˌisaˈias', 'θinkwˈɛnta', 'ˈi', 'sˈeɪs', 'asˈi', 'dˈixo', 'xˌeoβˈa', 'deɾˈetʃo', 'ˈi', 'xustˈiθja', 'pˈoɾke', 'estˈa', 'mˈi', 'salˈud', 'pˈaɾa', 'benˈiɾ', 'ˈi', 'mˈi', 'xustˈiθja', 'pˈaɾa']
# 2025-04-11 13:30:38,372 - INFO - Predicted Phonemes: []
# 2025-04-11 13:30:38,372 - INFO - Raw Predictions (first time step):
# [6.3762553e-03 5.2236430e-03 7.1334979e-04 ... 3.2413318e-05 3.3087355e-05
#  3.6499936e-05]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2025-04-11 13:30:38,469 - INFO -
# --- Prediction for: 10367_10282_000013 ---
# 2025-04-11 13:30:38,469 - INFO - True Phonemes:    ['sˈi', 'dˈel', 'sˈaβaðo', 'tˈu', 'pjˈe', 'dˈe', 'aθˈeɾ', 'tˈu', 'bˌoluntˈad', 'ˈen', 'mˈi', 'dˈia', 'sˈanto', 'ˈi', 'ˈal', 'sˈaβaðo', 'sˈanto', 'dˈe', 'xˌeoβˈa', 'ˈi', 'lˈo', 'nˈo', 'andˈando', 'ˈen', 'tˈus', 'kamˈinos', 'nˈi', 'buskˈando', 'tˈu', 'bˌoluntˈad', 'nˈi', 'aβlˈando', 'tˈus', 'palˈaβɾas']
# 2025-04-11 13:30:38,469 - INFO - Predicted Phonemes: []
# 2025-04-11 13:30:38,469 - INFO - Raw Predictions (first time step):
# [6.3762553e-03 5.2236430e-03 7.1334979e-04 ... 3.2413318e-05 3.3087355e-05
#  3.6499936e-05]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2025-04-11 13:30:38,568 - INFO -
# --- Prediction for: 10367_10282_000015 ---
# 2025-04-11 13:30:38,568 - INFO - True Phonemes:    ['nˈo', 'kˌonoθjˈeɾon', 'kamˈino', 'dˈe', 'pˈaθ', 'nˈi', 'ˈaɪ', 'deɾˈetʃo', 'ˈen', 'sˈus', 'kamˈinos', 'sˈus', 'sˈon', 'kwalkjˈeɾa', 'kˈe', 'pˈoɾ', 'ˈeʎas', 'fwˈeɾe', 'nˈo', 'pˈaθ', 'pˈoɾ', 'ˈesto', 'sˈe', 'ˌalexˈo', 'dˈe', 'nosˈotɾos', 'ˈel', 'xwˈiθjo', 'ˈi', 'nˈo', 'nˈos', 'ˌalkanθˈo', 'xustˈiθja', 'lˈuθ', 'ˈi', 'ˈe', 'akˈi', 'tinjˈeβlas', 'ˈi', 'ˈen', 'ˌoskuɾiðˈad']
# 2025-04-11 13:30:38,568 - INFO - Predicted Phonemes: []
# 2025-04-11 13:30:38,575 - INFO - Raw Predictions (first time step):
# [6.3762553e-03 5.2236430e-03 7.1334979e-04 ... 3.2413318e-05 3.3087355e-05
#  3.6499936e-05]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2025-04-11 13:30:38,659 - INFO -
# --- Prediction for: 10367_10282_000017 ---
# 2025-04-11 13:30:38,659 - INFO - True Phonemes:    ['aβjˈɛndo', 'ˈel', 'ʎeβˈaðo', 'ˈel', 'pekˈaðo', 'dˈe', 'mˈutʃos', 'ˈi', 'pˈoɾ', 'lˈos']
# 2025-04-11 13:30:38,659 - INFO - Predicted Phonemes: []
# 2025-04-11 13:30:38,659 - INFO - Raw Predictions (first time step):
# [6.3762553e-03 5.2236430e-03 7.1334979e-04 ... 3.2413318e-05 3.3087355e-05
#  3.6499936e-05]
# 2025-04-11 13:30:38,667 - WARNING - Example audio file not found at: C:\ASR\converted_audio\your_audio_file.wav
# 2025-04-11 13:30:38,669 - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2025-04-11 13:30:38,766 - INFO - ✅ Model and vocabulary saved (concatenated features with padding).
